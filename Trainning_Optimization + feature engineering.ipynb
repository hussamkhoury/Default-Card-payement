# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/ML homework/Copy of default of credit card clients.csv")

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [30000 rows x 25 columns]

# %% [markdown]
# # Helper Functions:

# %%
def preprocessing_(data):
    # get rid of missing values in MARRIAGE column
    data = data[data["MARRIAGE"] != 0]   
    
    # get rid of missing values in EDUCATION column
    data = data[data["EDUCATION"] != 0]    
    
    # discritize the AGE attribute to 6 interval
    data["AGE"] = pd.cut(data["AGE"], 6, labels=["AGE20", "AGE30", "AGE40", "AGE50", "AGE60", "AGE70"] )    
    #ordinal encoding
    encoder = OrdinalEncoder()
    # transform data
    data["AGE"] = encoder.fit_transform(np.array(data["AGE"]).reshape(-1, 1))
    
    return data

def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    """pretty print for confusion matrixes"""
    columnwidth = max([len(x) for x in labels] + [5])  # 5 is value length
    empty_cell = " " * columnwidth
    # Print header
    print("    " + empty_cell, end=" ")
    for label in labels:
        print("%{0}s".format(columnwidth) % label, end=" ")
    print()
    # Print rows
    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % label1, end=" ")
        for j in range(len(labels)):
            cell = "%{0}.1f".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            print(cell, end=" ")
        print()

        
def train_evaluate_val(model, x_train, y_train, folds, metrics):
    for metric in metrics:
        scores = cross_val_score(model, x_train, y_train, cv=folds, scoring = metric)
        print(f'{metric}:')
        print(f'Cross-validation: {scores}')
        print(f"Average: {scores.mean()}")
        print("----------------------------------------------------------")
    
def test_evaluate(model, x_test, y_test):
    prediction = model.predict(x_test)
    # prediction_prob = model.predict_proba(x_test)
    confusion = confusion_matrix(y_test, prediction)
    print("Confusion matrix",print_cm(confusion, ['Not pay', 'pay']))
    print('Accuracy: {:.2f}'.format(accuracy_score(y_test, prediction)))
    print('Precision: {:.2f}'.format(precision_score(y_test, prediction)))
    print('Recall: {:.2f}'.format(recall_score(y_test, prediction)))
    print('F1: {:.2f}'.format(f1_score(y_test, prediction)))
    print('AUC: {:.2f}'.format(roc_auc_score(y_test, prediction)))
    print(classification_report(y_test, prediction, target_names=['not pay', 'pay']))
    # precision_recall_curve(y_test, prediction_prob)

def optimize_model(model, x_train, y_train, parameters, metrics):
    for metric in metrics:
        print(f'{metric}:')
        grid_clf = GridSearchCV(model, param_grid = parameters, scoring = metric)
        grid_clf.fit(x_train, y_train)
        best_parameter = grid_clf.best_params_
        best_score = grid_clf.best_score_
        print(f"The best parameters: {best_parameter}\nThe best score: {best_score}\n")

# %% [markdown]
# # Prepare the data:

# %%
data = preprocessing_(data)

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [29932 rows x 25 columns]

# %% [markdown]
# # combinning features and generate a high level features:

# %% [markdown]
# Combination one: combin all the preivous payements history of every person which will make a new feature represent the dealy of every person for pay his bills

# %% [markdown]
# Make the new feature:("payment_history")

# %%
data["payment_delay"] = data['PAY_0'] + data['PAY_2'] + data['PAY_3'] + data['PAY_4'] + data['PAY_5'] + data['PAY_6']

# %%
data["payment_delay"]
# Out:
# 0       -2
# 1        3
# 2        0
# 3        0
# 4       -2
#         ..
# 29995    0
# 29996   -4
# 29997    8
# 29998   -1
# 29999    0
# Name: payment_delay, Length: 29932, dtype: int64

# %% [markdown]
# Make the new feature:("payment_delay_amount")

# %%
data['payment_delay_amount'] = (data['BILL_AMT1'] - data['PAY_AMT1']) + (data['BILL_AMT2'] - data['PAY_AMT2']) + (data['BILL_AMT3'] - data['PAY_AMT3']) + (data['BILL_AMT4'] - data['PAY_AMT4']) + (data['BILL_AMT5'] - data['PAY_AMT5']) + (data['BILL_AMT6'] - data['PAY_AMT6'])

# %%
data['payment_delay_amount']
# Out:
# 0          7015
# 1         12077
# 2         90635
# 3        222946
# 4         50290
#           ...
# 29995    682799
# 29996      6692
# 29997     39196
# 29998    119430
# 29999    222566
# Name: payment_delay_amount, Length: 29932, dtype: int64

# %% [markdown]
# Make the new feature:("total_payment_amount")

# %%
data["total_payment_amount"] = data['PAY_AMT1'] + data['PAY_AMT2'] + data['PAY_AMT3'] + data['PAY_AMT4'] + data['PAY_AMT5'] + data['PAY_AMT6']

# %%
data["total_payment_amount"]
# Out:
# 0           689
# 1          5000
# 2         11018
# 3          8388
# 4         59049
#           ...
# 29995     42550
# 29996     14490
# 29997     31300
# 29998    147181
# 29999      8308
# Name: total_payment_amount, Length: 29932, dtype: int64

# %% [markdown]
# # Split the data:

# %%
y = data["default payment next month"]
data = data.drop("default payment next month", axis=1)

# x_train, x_test, y_train, y_test = train_test_split(data, y, test_size=0.2, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(data[['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'payment_delay', 'payment_delay_amount', 'total_payment_amount']], y, test_size=0.2, random_state=42)#'LIMIT_BAL' 'delay_amount'

# %% [markdown]
# Normalization:

# %%
scaler = preprocessing.StandardScaler().fit(np.array(x_train["payment_delay_amount"]).reshape(-1, 1))
x_train["payment_delay_amount"] = scaler.transform(np.array(x_train["payment_delay_amount"]).reshape(-1, 1))
x_test["payment_delay_amount"] = scaler.transform(np.array(x_test["payment_delay_amount"]).reshape(-1, 1))

scaler1 = preprocessing.StandardScaler().fit(np.array(x_train["total_payment_amount"]).reshape(-1, 1))
x_train["total_payment_amount"] = scaler1.transform(np.array(x_train["total_payment_amount"]).reshape(-1, 1))
x_test["total_payment_amount"] = scaler1.transform(np.array(x_test["total_payment_amount"]).reshape(-1, 1))

scaler2 = preprocessing.StandardScaler().fit(np.array(x_train["LIMIT_BAL"]).reshape(-1, 1))
x_train["LIMIT_BAL"] = scaler2.transform(np.array(x_train["LIMIT_BAL"]).reshape(-1, 1))
x_test["LIMIT_BAL"] = scaler2.transform(np.array(x_test["LIMIT_BAL"]).reshape(-1, 1))

x_train
# Out:
#        LIMIT_BAL  SEX  ...  payment_delay_amount  total_payment_amount
# 8759   -1.135178    2  ...             -0.556956             -0.409725
# 29948   0.945432    1  ...             -0.565613              0.169065
# 29155  -1.135178    2  ...             -0.460194             -0.466397
# 11522   1.022492    2  ...             -0.655241             -0.461244
# 8242    0.328955    2  ...             -0.654879             -0.548229
# ...          ...  ...  ...                   ...                   ...
# 29870  -1.212238    1  ...             -0.507643             -0.467233
# 5402   -0.903999    1  ...             -0.292742             -0.434501
# 863    -1.212238    2  ...             -0.499167             -0.435128
# 15824  -0.672820    2  ...             -0.601755             -0.469514
# 23706   1.870148    2  ...              3.161896              0.383253
#
# [23945 rows x 8 columns]

# %% [markdown]
# # Train & Evaluate:

# %% [markdown]
# Helper Functions:

# %%
def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    """pretty print for confusion matrixes"""
    columnwidth = max([len(x) for x in labels] + [5])  # 5 is value length
    empty_cell = " " * columnwidth
    # Print header
    print("    " + empty_cell, end=" ")
    for label in labels:
        print("%{0}s".format(columnwidth) % label, end=" ")
    print()
    # Print rows
    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % label1, end=" ")
        for j in range(len(labels)):
            cell = "%{0}.1f".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            print(cell, end=" ")
        print()
        
def train_evaluate_val(model, x_train, y_train, folds, metrics):
    for metric in metrics:
        scores = cross_val_score(model, x_train, y_train, cv=folds, scoring = metric)
        print(f'{metric}:')
        print(f'Cross-validation: {scores}')
        print(f"Average: {scores.mean()}")
        print("----------------------------------------------------------")
    
def test_evaluate(model, x_test, y_test):
    prediction = model.predict(x_test)
    confusion = confusion_matrix(y_test, prediction)
    print("Confusion matrix",print_cm(confusion, ['Not pay', 'pay']))
    print('Accuracy: {:.2f}'.format(accuracy_score(y_test, prediction)))
    print('Precision: {:.2f}'.format(precision_score(y_test, prediction)))
    print('Recall: {:.2f}'.format(recall_score(y_test, prediction)))
    print('F1: {:.2f}'.format(f1_score(y_test, prediction)))
    print('AUC: {:.2f}'.format(roc_auc_score(y_test, prediction)))
    print(classification_report(y_test, prediction, target_names=['not pay', 'pay']))

def optimize_model(model, x_train, y_train, parameters, metrics):
    for metric in metrics:
        print(f'{metric}:')
        grid_clf = GridSearchCV(model, param_grid = parameters, scoring = metric)
        grid_clf.fit(x_train, y_train)
        best_parameter = grid_clf.best_params_
        best_score = grid_clf.best_score_
        print(f"The best parameters: {best_parameter}\nThe best score: {best_score}\n")

# %%
metrics = ["accuracy", 'precision', 'recall', 'f1', 'roc_auc']

# %% [markdown]
# Logistic Regression:

# %%
l_g_grid_values = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
l_g = LogisticRegression()

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(l_g, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.79369388 0.80037586 0.7993318  0.79661725 0.79766131]
# Average: 0.7975360200459386
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.640625   0.72340426 0.71929825 0.66539924 0.69166667]
# Average: 0.6880786814287154
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.15471698 0.1602262  0.15457116 0.16493874 0.15645617]
# Average: 0.15818185051482228
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.24924012 0.26234568 0.25446082 0.26435045 0.25518832]
# Average: 0.2571170785574954
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.69449901 0.70601124 0.68665495 0.68453811 0.70046263]
# Average: 0.694433187339832
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
l_g = LogisticRegression()
optimize_model(l_g, x_train, y_train, l_g_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'C': 10}
# The best score: 0.7975777824180413
#
# precision:
# The best parameters: {'C': 0.001}
# The best score: 0.690950906535812
#
# recall:
# The best parameters: {'C': 10}
# The best score: 0.15837035192858287
#
# f1:
# The best parameters: {'C': 10}
# The best score: 0.25738502833713883
#
# roc_auc:
# The best parameters: {'C': 100}
# The best score: 0.6944373337325617

# %% [markdown]
# Final evaluation on the test data:

# %%
l_g = LogisticRegression(C=10)
l_g.fit(x_train, y_train)
test_evaluate(l_g, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  4552.0   108.0
#         pay  1090.0   237.0
# Confusion matrix None
# Accuracy: 0.80
# Precision: 0.69
# Recall: 0.18
# F1: 0.28
# AUC: 0.58
#               precision    recall  f1-score   support
#
#      not pay       0.81      0.98      0.88      4660
#          pay       0.69      0.18      0.28      1327
#
#     accuracy                           0.80      5987
#    macro avg       0.75      0.58      0.58      5987
# weighted avg       0.78      0.80      0.75      5987

# %% [markdown]
# Decision Tree:

# %%
d_t = DecisionTreeClassifier()

# %%
d_t_grid_values = {'max_depth': [100, 20, 30, 50, 80, 100],
                    'criterion': ["gini", "entropy"],
                   'splitter': ["best", "random"],}

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(d_t, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.71413656 0.72374191 0.72562122 0.71538943 0.7218626 ]
# Average: 0.7201503445395698
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.37190813 0.38992042 0.375      0.36915078 0.375     ]
# Average: 0.3761958663015355
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.4009434  0.40622055 0.37794533 0.4005655  0.39585297]
# Average: 0.3963055501218146
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.3759058  0.39293798 0.37807183 0.37934186 0.38273921]
# Average: 0.3817993376921711
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.59974676 0.61599802 0.60118767 0.5996365  0.60550049]
# Average: 0.6044138872323763
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
d_t = DecisionTreeClassifier()
                
optimize_model(d_t, x_train, y_train, d_t_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'criterion': 'entropy', 'max_depth': 20, 'splitter': 'random'}
# The best score: 0.7533931927333473
#
# precision:
# The best parameters: {'criterion': 'entropy', 'max_depth': 20, 'splitter': 'random'}
# The best score: 0.4246480023863602
#
# recall:
# The best parameters: {'criterion': 'gini', 'max_depth': 30, 'splitter': 'random'}
# The best score: 0.394983728415699
#
# f1:
# The best parameters: {'criterion': 'gini', 'max_depth': 20, 'splitter': 'best'}
# The best score: 0.391463857871809
#
# roc_auc:
# The best parameters: {'criterion': 'entropy', 'max_depth': 20, 'splitter': 'best'}
# The best score: 0.6278238752109169

# %% [markdown]
# Final evaluation on the test data:

# %%
d_t = DecisionTreeClassifier(max_depth = 100, criterion = 'gini', splitter = 'random')
d_t.fit(x_train, y_train)
test_evaluate(d_t, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  3793.0   867.0
#         pay   816.0   511.0
# Confusion matrix None
# Accuracy: 0.72
# Precision: 0.37
# Recall: 0.39
# F1: 0.38
# AUC: 0.60
#               precision    recall  f1-score   support
#
#      not pay       0.82      0.81      0.82      4660
#          pay       0.37      0.39      0.38      1327
#
#     accuracy                           0.72      5987
#    macro avg       0.60      0.60      0.60      5987
# weighted avg       0.72      0.72      0.72      5987

# %% [markdown]
# Random Forest:

# %%
r_f = RandomForestClassifier()

# %%
r_f_grid_values = {'max_depth': [10, 20, 30, 50, 100],
                    'n_estimators': [10, 20, 40, 80, 100],
                    'criterion': ["gini", "entropy"]}

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(r_f, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.78930883 0.80329923 0.79912299 0.79432032 0.79891418]
# Average: 0.796993109208603
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.53821138 0.59967051 0.59369202 0.56587838 0.59628378]
# Average: 0.5787472154495672
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.31603774 0.34024505 0.31008483 0.31762488 0.332705  ]
# Average: 0.32333949815944374
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.4019025  0.43625378 0.40272615 0.41581786 0.42874396]
# Average: 0.4170888472077233
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.73230228 0.76271752 0.73332827 0.73788001 0.74510885]
# Average: 0.7422673859421544
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
r_f = RandomForestClassifier()
                
optimize_model(r_f, x_train, y_train, r_f_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 80}
# The best score: 0.807600751722698
#
# precision:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100}
# The best score: 0.6293491544481786
#
# recall:
# The best parameters: {'criterion': 'gini', 'max_depth': 30, 'n_estimators': 100}
# The best score: 0.3314468372663738
#
# f1:
# The best parameters: {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 80}
# The best score: 0.41968958999507616
#
# roc_auc:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100}
# The best score: 0.7672839296570468

# %% [markdown]
# Final evaluation on the test data:

# %%
r_f = RandomForestClassifier(max_depth = 20, n_estimators = 40, criterion = 'entropy')
r_f.fit(x_train, y_train)
test_evaluate(r_f, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  4360.0   300.0
#         pay   933.0   394.0
# Confusion matrix None
# Accuracy: 0.79
# Precision: 0.57
# Recall: 0.30
# F1: 0.39
# AUC: 0.62
#               precision    recall  f1-score   support
#
#      not pay       0.82      0.94      0.88      4660
#          pay       0.57      0.30      0.39      1327
#
#     accuracy                           0.79      5987
#    macro avg       0.70      0.62      0.63      5987
# weighted avg       0.77      0.79      0.77      5987

# %% [markdown]
# # Deep Neural network:

# %% [markdown]
# Metrics:

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', precision_m, recall_m, f1_m,])
# fit the keras model on the dataset
model.fit(np.array(x_train), np.array(y_train), epochs=50, batch_size=100, validation_split=0.2)
model.evaluate(x=x_test, y=y_test)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 17s 7ms/step - loss: 0.4999 - accuracy: 0.7977 - precision_m: 0.5931 - recall_m: 0.2825 - f1_m: 0.3688 - val_loss: 0.4545 - val_accuracy: 0.8094 - val_precision_m: 0.6205 - val_recall_m: 0.3692 - val_f1_m: 0.4568
# Epoch 2/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.8058 - precision_m: 0.6111 - recall_m: 0.3312 - f1_m: 0.4217 - val_loss: 0.4523 - val_accuracy: 0.8066 - val_precision_m: 0.6332 - val_recall_m: 0.2997 - val_f1_m: 0.4006
# Epoch 3/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4560 - accuracy: 0.8055 - precision_m: 0.6310 - recall_m: 0.3313 - f1_m: 0.4247 - val_loss: 0.4506 - val_accuracy: 0.8106 - val_precision_m: 0.6294 - val_recall_m: 0.3615 - val_f1_m: 0.4529
# Epoch 4/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4611 - accuracy: 0.8020 - precision_m: 0.6065 - recall_m: 0.3180 - f1_m: 0.4095 - val_loss: 0.4497 - val_accuracy: 0.8068 - val_precision_m: 0.6291 - val_recall_m: 0.3112 - val_f1_m: 0.4105
# Epoch 5/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4578 - accuracy: 0.8032 - precision_m: 0.6218 - recall_m: 0.3144 - f1_m: 0.4092 - val_loss: 0.4485 - val_accuracy: 0.8102 - val_precision_m: 0.6369 - val_recall_m: 0.3417 - val_f1_m: 0.4386
# Epoch 6/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4507 - accuracy: 0.8084 - precision_m: 0.6263 - recall_m: 0.3168 - f1_m: 0.4144 - val_loss: 0.4487 - val_accuracy: 0.8102 - val_precision_m: 0.6298 - val_recall_m: 0.3559 - val_f1_m: 0.4486
# Epoch 7/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4576 - accuracy: 0.8001 - precision_m: 0.6180 - recall_m: 0.3271 - f1_m: 0.4190 - val_loss: 0.4485 - val_accuracy: 0.8056 - val_precision_m: 0.6294 - val_recall_m: 0.2923 - val_f1_m: 0.3928
# Epoch 8/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4508 - accuracy: 0.8076 - precision_m: 0.6216 - recall_m: 0.3196 - f1_m: 0.4132 - val_loss: 0.4467 - val_accuracy: 0.8087 - val_precision_m: 0.6340 - val_recall_m: 0.3317 - val_f1_m: 0.4289
# Epoch 9/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8069 - precision_m: 0.6350 - recall_m: 0.3044 - f1_m: 0.4022 - val_loss: 0.4457 - val_accuracy: 0.8102 - val_precision_m: 0.6349 - val_recall_m: 0.3460 - val_f1_m: 0.4411
# Epoch 10/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.8087 - precision_m: 0.6328 - recall_m: 0.3460 - f1_m: 0.4397 - val_loss: 0.4462 - val_accuracy: 0.8081 - val_precision_m: 0.6419 - val_recall_m: 0.2974 - val_f1_m: 0.4001
# Epoch 11/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.8018 - precision_m: 0.6033 - recall_m: 0.2991 - f1_m: 0.3909 - val_loss: 0.4463 - val_accuracy: 0.8094 - val_precision_m: 0.6281 - val_recall_m: 0.3481 - val_f1_m: 0.4417
# Epoch 12/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4519 - accuracy: 0.8025 - precision_m: 0.6254 - recall_m: 0.3086 - f1_m: 0.4041 - val_loss: 0.4463 - val_accuracy: 0.8062 - val_precision_m: 0.6357 - val_recall_m: 0.2902 - val_f1_m: 0.3921
# Epoch 13/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4499 - accuracy: 0.8033 - precision_m: 0.6131 - recall_m: 0.2922 - f1_m: 0.3898 - val_loss: 0.4458 - val_accuracy: 0.8075 - val_precision_m: 0.6312 - val_recall_m: 0.3072 - val_f1_m: 0.4070
# Epoch 14/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.8103 - precision_m: 0.6218 - recall_m: 0.3211 - f1_m: 0.4150 - val_loss: 0.4447 - val_accuracy: 0.8081 - val_precision_m: 0.6343 - val_recall_m: 0.3124 - val_f1_m: 0.4125
# Epoch 15/50
# 192/192 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.8037 - precision_m: 0.6156 - recall_m: 0.3025 - f1_m: 0.3963 - val_loss: 0.4459 - val_accuracy: 0.8075 - val_precision_m: 0.6301 - val_recall_m: 0.3151 - val_f1_m: 0.4141
# Epoch 16/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.8060 - precision_m: 0.6021 - recall_m: 0.2957 - f1_m: 0.3883 - val_loss: 0.4444 - val_accuracy: 0.8075 - val_precision_m: 0.6438 - val_recall_m: 0.2889 - val_f1_m: 0.3924
# Epoch 17/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4516 - accuracy: 0.8033 - precision_m: 0.6221 - recall_m: 0.3087 - f1_m: 0.4049 - val_loss: 0.4447 - val_accuracy: 0.8066 - val_precision_m: 0.6405 - val_recall_m: 0.2850 - val_f1_m: 0.3878
# Epoch 18/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4462 - accuracy: 0.8077 - precision_m: 0.6302 - recall_m: 0.3165 - f1_m: 0.4107 - val_loss: 0.4456 - val_accuracy: 0.8075 - val_precision_m: 0.6191 - val_recall_m: 0.3483 - val_f1_m: 0.4394
# Epoch 19/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4537 - accuracy: 0.8006 - precision_m: 0.5976 - recall_m: 0.3046 - f1_m: 0.3962 - val_loss: 0.4458 - val_accuracy: 0.8087 - val_precision_m: 0.6354 - val_recall_m: 0.3203 - val_f1_m: 0.4196
# Epoch 20/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4442 - accuracy: 0.8113 - precision_m: 0.6418 - recall_m: 0.3226 - f1_m: 0.4210 - val_loss: 0.4442 - val_accuracy: 0.8058 - val_precision_m: 0.6332 - val_recall_m: 0.2861 - val_f1_m: 0.3878
# Epoch 21/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4429 - accuracy: 0.8080 - precision_m: 0.6097 - recall_m: 0.2954 - f1_m: 0.3904 - val_loss: 0.4442 - val_accuracy: 0.8075 - val_precision_m: 0.6346 - val_recall_m: 0.3073 - val_f1_m: 0.4079
# Epoch 22/50
# 192/192 [==============================] - 0s 3ms/step - loss: 0.4461 - accuracy: 0.8061 - precision_m: 0.6285 - recall_m: 0.3165 - f1_m: 0.4133 - val_loss: 0.4453 - val_accuracy: 0.8048 - val_precision_m: 0.6279 - val_recall_m: 0.2854 - val_f1_m: 0.3863
# Epoch 23/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4445 - accuracy: 0.8088 - precision_m: 0.6503 - recall_m: 0.3310 - f1_m: 0.4313 - val_loss: 0.4465 - val_accuracy: 0.8068 - val_precision_m: 0.6345 - val_recall_m: 0.2975 - val_f1_m: 0.3988
# Epoch 24/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.8071 - precision_m: 0.6388 - recall_m: 0.3284 - f1_m: 0.4238 - val_loss: 0.4430 - val_accuracy: 0.8091 - val_precision_m: 0.6314 - val_recall_m: 0.3404 - val_f1_m: 0.4357
# Epoch 25/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.8074 - precision_m: 0.6189 - recall_m: 0.3129 - f1_m: 0.4056 - val_loss: 0.4460 - val_accuracy: 0.8091 - val_precision_m: 0.6208 - val_recall_m: 0.3653 - val_f1_m: 0.4539
# Epoch 26/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8037 - precision_m: 0.5932 - recall_m: 0.3052 - f1_m: 0.3954 - val_loss: 0.4423 - val_accuracy: 0.8102 - val_precision_m: 0.6416 - val_recall_m: 0.3306 - val_f1_m: 0.4297
# Epoch 27/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.8035 - precision_m: 0.6273 - recall_m: 0.3250 - f1_m: 0.4206 - val_loss: 0.4430 - val_accuracy: 0.8096 - val_precision_m: 0.6376 - val_recall_m: 0.3310 - val_f1_m: 0.4295
# Epoch 28/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.8065 - precision_m: 0.6203 - recall_m: 0.3155 - f1_m: 0.4112 - val_loss: 0.4434 - val_accuracy: 0.8087 - val_precision_m: 0.6232 - val_recall_m: 0.3553 - val_f1_m: 0.4469
# Epoch 29/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.8092 - precision_m: 0.6258 - recall_m: 0.3318 - f1_m: 0.4253 - val_loss: 0.4438 - val_accuracy: 0.8077 - val_precision_m: 0.6143 - val_recall_m: 0.3632 - val_f1_m: 0.4505
# Epoch 30/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4474 - accuracy: 0.8072 - precision_m: 0.6360 - recall_m: 0.3359 - f1_m: 0.4300 - val_loss: 0.4445 - val_accuracy: 0.8094 - val_precision_m: 0.6449 - val_recall_m: 0.3167 - val_f1_m: 0.4182
# Epoch 31/50
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4482 - accuracy: 0.8041 - precision_m: 0.6254 - recall_m: 0.3177 - f1_m: 0.4166 - val_loss: 0.4436 - val_accuracy: 0.8094 - val_precision_m: 0.6367 - val_recall_m: 0.3294 - val_f1_m: 0.4272
# Epoch 32/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4514 - accuracy: 0.8016 - precision_m: 0.6166 - recall_m: 0.3132 - f1_m: 0.4057 - val_loss: 0.4439 - val_accuracy: 0.8100 - val_precision_m: 0.6374 - val_recall_m: 0.3401 - val_f1_m: 0.4370
# Epoch 33/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4477 - accuracy: 0.8038 - precision_m: 0.6226 - recall_m: 0.3271 - f1_m: 0.4220 - val_loss: 0.4436 - val_accuracy: 0.8087 - val_precision_m: 0.6297 - val_recall_m: 0.3349 - val_f1_m: 0.4308
# Epoch 34/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.4433 - accuracy: 0.8072 - precision_m: 0.6251 - recall_m: 0.3095 - f1_m: 0.4075 - val_loss: 0.4460 - val_accuracy: 0.8089 - val_precision_m: 0.6205 - val_recall_m: 0.3624 - val_f1_m: 0.4511
# Epoch 35/50
# 192/192 [==============================] - 0s 3ms/step - loss: 0.4514 - accuracy: 0.8045 - precision_m: 0.6309 - recall_m: 0.3267 - f1_m: 0.4222 - val_loss: 0.4484 - val_accuracy: 0.8094 - val_precision_m: 0.6313 - val_recall_m: 0.3412 - val_f1_m: 0.4363
# Epoch 36/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.8077 - precision_m: 0.6345 - recall_m: 0.3147 - f1_m: 0.4106 - val_loss: 0.4428 - val_accuracy: 0.8077 - val_precision_m: 0.6254 - val_recall_m: 0.3413 - val_f1_m: 0.4351
# Epoch 37/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.8067 - precision_m: 0.6254 - recall_m: 0.3182 - f1_m: 0.4129 - val_loss: 0.4439 - val_accuracy: 0.8100 - val_precision_m: 0.6410 - val_recall_m: 0.3336 - val_f1_m: 0.4312
# Epoch 38/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.8036 - precision_m: 0.6297 - recall_m: 0.3349 - f1_m: 0.4287 - val_loss: 0.4434 - val_accuracy: 0.8091 - val_precision_m: 0.6443 - val_recall_m: 0.3169 - val_f1_m: 0.4175
# Epoch 39/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.8058 - precision_m: 0.6405 - recall_m: 0.3270 - f1_m: 0.4242 - val_loss: 0.4429 - val_accuracy: 0.8085 - val_precision_m: 0.6344 - val_recall_m: 0.3282 - val_f1_m: 0.4253
# Epoch 40/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.8066 - precision_m: 0.6269 - recall_m: 0.3135 - f1_m: 0.4102 - val_loss: 0.4442 - val_accuracy: 0.8081 - val_precision_m: 0.6202 - val_recall_m: 0.3522 - val_f1_m: 0.4435
# Epoch 41/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4378 - accuracy: 0.8085 - precision_m: 0.6251 - recall_m: 0.3496 - f1_m: 0.4384 - val_loss: 0.4433 - val_accuracy: 0.8077 - val_precision_m: 0.6240 - val_recall_m: 0.3385 - val_f1_m: 0.4322
# Epoch 42/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.8065 - precision_m: 0.6330 - recall_m: 0.3265 - f1_m: 0.4233 - val_loss: 0.4443 - val_accuracy: 0.8064 - val_precision_m: 0.6475 - val_recall_m: 0.2788 - val_f1_m: 0.3833
# Epoch 43/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.8068 - precision_m: 0.6352 - recall_m: 0.3080 - f1_m: 0.4042 - val_loss: 0.4445 - val_accuracy: 0.8094 - val_precision_m: 0.6469 - val_recall_m: 0.3167 - val_f1_m: 0.4175
# Epoch 44/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.8113 - precision_m: 0.6285 - recall_m: 0.3363 - f1_m: 0.4292 - val_loss: 0.4454 - val_accuracy: 0.8085 - val_precision_m: 0.6297 - val_recall_m: 0.3342 - val_f1_m: 0.4299
# Epoch 45/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4485 - accuracy: 0.8070 - precision_m: 0.6497 - recall_m: 0.3212 - f1_m: 0.4199 - val_loss: 0.4458 - val_accuracy: 0.8083 - val_precision_m: 0.6245 - val_recall_m: 0.3460 - val_f1_m: 0.4384
# Epoch 46/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.8089 - precision_m: 0.6274 - recall_m: 0.3366 - f1_m: 0.4286 - val_loss: 0.4430 - val_accuracy: 0.8079 - val_precision_m: 0.6301 - val_recall_m: 0.3357 - val_f1_m: 0.4311
# Epoch 47/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.8103 - precision_m: 0.6235 - recall_m: 0.3273 - f1_m: 0.4216 - val_loss: 0.4429 - val_accuracy: 0.8087 - val_precision_m: 0.6362 - val_recall_m: 0.3304 - val_f1_m: 0.4272
# Epoch 48/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.8143 - precision_m: 0.6381 - recall_m: 0.3164 - f1_m: 0.4158 - val_loss: 0.4453 - val_accuracy: 0.8094 - val_precision_m: 0.6391 - val_recall_m: 0.3272 - val_f1_m: 0.4252
# Epoch 49/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4452 - accuracy: 0.8022 - precision_m: 0.6194 - recall_m: 0.3201 - f1_m: 0.4144 - val_loss: 0.4483 - val_accuracy: 0.8071 - val_precision_m: 0.6463 - val_recall_m: 0.2874 - val_f1_m: 0.3903
# Epoch 50/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.8055 - precision_m: 0.6324 - recall_m: 0.3102 - f1_m: 0.4075 - val_loss: 0.4460 - val_accuracy: 0.8089 - val_precision_m: 0.6412 - val_recall_m: 0.3199 - val_f1_m: 0.4193
# 188/188 [==============================] - 1s 2ms/step - loss: 0.4522 - accuracy: 0.8037 - precision_m: 0.5924 - recall_m: 0.2988 - f1_m: 0.3704
# [0.4522141218185425,
#  0.803741455078125,
#  0.5924476981163025,
#  0.29877156019210815,
#  0.37035953998565674]
