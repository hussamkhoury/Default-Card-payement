# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import OrdinalEncoder
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/ML homework/Copy of default of credit card clients.csv")

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
data.drop('ID', axis=1)
# Out:
#        LIMIT_BAL  SEX  ...  PAY_AMT6  default payment next month
# 0          20000    2  ...         0                           1
# 1         120000    2  ...      2000                           1
# 2          90000    2  ...      5000                           0
# 3          50000    2  ...      1000                           0
# 4          50000    1  ...       679                           0
# ...          ...  ...  ...       ...                         ...
# 29995     220000    1  ...      1000                           0
# 29996     150000    1  ...         0                           0
# 29997      30000    1  ...      3100                           1
# 29998      80000    1  ...      1804                           1
# 29999      50000    1  ...      1000                           1
#
# [30000 rows x 24 columns]

# %% [markdown]
# # Helper Function

# %%
def preprocessing_(data):
    # get rid of missing values in MARRIAGE column
    data = data[data["MARRIAGE"] != 0]   
    
    # get rid of missing values in EDUCATION column
    data = data[data["EDUCATION"] != 0]    
    
    # discritize the AGE attribute to 6 interval
    data["AGE"] = pd.cut(data["AGE"], 6, labels=["AGE20", "AGE30", "AGE40", "AGE50", "AGE60", "AGE70"] )    
    #ordinal encoding
    encoder = OrdinalEncoder()
    # transform data
    data["AGE"] = encoder.fit_transform(np.array(data["AGE"]).reshape(-1, 1))
    
    return data

def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    """pretty print for confusion matrixes"""
    columnwidth = max([len(x) for x in labels] + [5])  # 5 is value length
    empty_cell = " " * columnwidth
    # Print header
    print("    " + empty_cell, end=" ")
    for label in labels:
        print("%{0}s".format(columnwidth) % label, end=" ")
    print()
    # Print rows
    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % label1, end=" ")
        for j in range(len(labels)):
            cell = "%{0}.1f".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            print(cell, end=" ")
        print()

        
def train_evaluate_val(model, x_train, y_train, folds, metrics):
    for metric in metrics:
        scores = cross_val_score(model, x_train, y_train, cv=folds, scoring = metric)
        print(f'{metric}:')
        print(f'Cross-validation: {scores}')
        print(f"Average: {scores.mean()}")
        print("----------------------------------------------------------")
    
def test_evaluate(model, x_test, y_test):
    prediction = model.predict(x_test)
    # prediction_prob = model.predict_proba(x_test)
    confusion = confusion_matrix(y_test, prediction)
    print("Confusion matrix",print_cm(confusion, ['Not pay', 'pay']))
    print('Accuracy: {:.2f}'.format(accuracy_score(y_test, prediction)))
    print('Precision: {:.2f}'.format(precision_score(y_test, prediction)))
    print('Recall: {:.2f}'.format(recall_score(y_test, prediction)))
    print('F1: {:.2f}'.format(f1_score(y_test, prediction)))
    print('AUC: {:.2f}'.format(roc_auc_score(y_test, prediction)))
    print(classification_report(y_test, prediction, target_names=['not pay', 'pay']))
    # precision_recall_curve(y_test, prediction_prob)

def optimize_model(model, x_train, y_train, parameters, metrics):
    for metric in metrics:
        print(f'{metric}:')
        grid_clf = GridSearchCV(model, param_grid = parameters, scoring = metric)
        grid_clf.fit(x_train, y_train)
        best_parameter = grid_clf.best_params_
        best_score = grid_clf.best_score_
        print(f"The best parameters: {best_parameter}\nThe best score: {best_score}\n")

# %% [markdown]
# # Prepare the data:

# %%
data = preprocessing_(data)

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [29932 rows x 25 columns]

# %% [markdown]
# # Split the data:

# %%
y = data["default payment next month"]
data = data.drop("default payment next month", axis=1)

x_train, x_test, y_train, y_test = train_test_split(data, y, test_size=0.2, random_state=42)

# %% [markdown]
# Normalization:

# %%
scaler2 = preprocessing.StandardScaler().fit(np.array(x_train["LIMIT_BAL"]).reshape(-1, 1))
x_train["LIMIT_BAL"] = scaler2.transform(np.array(x_train["LIMIT_BAL"]).reshape(-1, 1))
x_test["LIMIT_BAL"] = scaler2.transform(np.array(x_test["LIMIT_BAL"]).reshape(-1, 1))

scaler3 = preprocessing.StandardScaler().fit(np.array(x_train["BILL_AMT1"]).reshape(-1, 1))
x_train["BILL_AMT1"] = scaler3.transform(np.array(x_train["BILL_AMT1"]).reshape(-1, 1))
x_train["BILL_AMT2"] = scaler3.transform(np.array(x_train["BILL_AMT2"]).reshape(-1, 1))
x_train["BILL_AMT3"] = scaler3.transform(np.array(x_train["BILL_AMT3"]).reshape(-1, 1))
x_train["BILL_AMT4"] = scaler3.transform(np.array(x_train["BILL_AMT4"]).reshape(-1, 1))
x_train["BILL_AMT5"] = scaler3.transform(np.array(x_train["BILL_AMT5"]).reshape(-1, 1))
x_train["BILL_AMT6"] = scaler3.transform(np.array(x_train["BILL_AMT6"]).reshape(-1, 1))

x_test["BILL_AMT1"] = scaler2.transform(np.array(x_test["BILL_AMT1"]).reshape(-1, 1))
x_test["BILL_AMT2"] = scaler2.transform(np.array(x_test["BILL_AMT2"]).reshape(-1, 1))
x_test["BILL_AMT3"] = scaler2.transform(np.array(x_test["BILL_AMT3"]).reshape(-1, 1))
x_test["BILL_AMT4"] = scaler2.transform(np.array(x_test["BILL_AMT4"]).reshape(-1, 1))
x_test["BILL_AMT5"] = scaler2.transform(np.array(x_test["BILL_AMT5"]).reshape(-1, 1))
x_test["BILL_AMT6"] = scaler2.transform(np.array(x_test["BILL_AMT6"]).reshape(-1, 1))

scaler4 = preprocessing.StandardScaler().fit(np.array(x_train["PAY_AMT1"]).reshape(-1, 1))
x_train["PAY_AMT1"] = scaler4.transform(np.array(x_train["PAY_AMT1"]).reshape(-1, 1))
x_train["PAY_AMT2"] = scaler4.transform(np.array(x_train["PAY_AMT2"]).reshape(-1, 1))
x_train["PAY_AMT3"] = scaler4.transform(np.array(x_train["PAY_AMT3"]).reshape(-1, 1))
x_train["PAY_AMT4"] = scaler4.transform(np.array(x_train["PAY_AMT4"]).reshape(-1, 1))
x_train["PAY_AMT5"] = scaler4.transform(np.array(x_train["PAY_AMT5"]).reshape(-1, 1))
x_train["PAY_AMT6"] = scaler4.transform(np.array(x_train["PAY_AMT6"]).reshape(-1, 1))

x_test["PAY_AMT1"] = scaler4.transform(np.array(x_test["PAY_AMT1"]).reshape(-1, 1))
x_test["PAY_AMT2"] = scaler4.transform(np.array(x_test["PAY_AMT2"]).reshape(-1, 1))
x_test["PAY_AMT3"] = scaler4.transform(np.array(x_test["PAY_AMT3"]).reshape(-1, 1))
x_test["PAY_AMT4"] = scaler4.transform(np.array(x_test["PAY_AMT4"]).reshape(-1, 1))
x_test["PAY_AMT5"] = scaler4.transform(np.array(x_test["PAY_AMT5"]).reshape(-1, 1))
x_test["PAY_AMT6"] = scaler4.transform(np.array(x_test["PAY_AMT6"]).reshape(-1, 1))

# %%
x_train
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  ...  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 8759    8760  -1.135178    2          1  ... -0.347201 -0.152203 -0.260507 -0.306404
# 29948  29949   0.945432    1          1  ... -0.231120 -0.355871 -0.356126 -0.356126
# 29155  29156  -1.135178    2          2  ... -0.164888 -0.356126 -0.356126 -0.356126
# 11522  11523   1.022492    2          1  ... -0.335982 -0.298882 -0.308444 -0.308444
# 8242    8243   0.328955    2          2  ... -0.356126 -0.356126 -0.356126 -0.356126
# ...      ...        ...  ...        ...  ...       ...       ...       ...       ...
# 29870  29871  -1.212238    1          2  ... -0.279631 -0.334516 -0.333751 -0.331010
# 5402    5403  -0.903999    1          1  ... -0.324253 -0.326866 -0.324253 -0.324253
# 863      864  -1.212238    2          2  ... -0.292380 -0.334898 -0.336301 -0.335600
# 15824  15825  -0.672820    2          2  ... -0.354787 -0.356126 -0.356126 -0.356126
# 23706  23707   1.870148    2          2  ...  0.281332  0.121967  0.153840  0.153840
#
# [23945 rows x 24 columns]

# %% [markdown]
# # Undersampling:

# %%
# the unbalanecd classes
class_0 = x_train[y_train == 0]
class_1 = x_train[y_train == 1]

print("before undersampling:\n")
print(f"not payed class: {len(class_0)}\n") #18641

print(f"payed class: {len(class_1)}\n") #5304

# under sample the dominent class(not payed)
class_0 = class_0[0:6001]
print("after undersampling:\n")
print(f"not payed class: {len(class_0)}\n")
# adding label as not payed
y_0 = np.zeros(len(class_0))
y_0 = pd.DataFrame(y_0, columns=["label"])

print(f"payed class: {len(class_1)}\n")
# adding label as payed
y_1 = np.ones(len(class_1))
y_1 = pd.DataFrame(y_1, columns=["label"])

# concatinate the new balanced data
undersampling_data_samples = pd.concat([class_0, class_1], ignore_index=True)
undersampling_data_label = pd.concat([y_0, y_1], ignore_index=True)
undersampling_data_samples["label"] = undersampling_data_label


# shuffling the data
undersampling_data = shuffle(undersampling_data_samples)
undersampling_data
# Out:
# before undersampling:
#
# not payed class: 23301
#
# payed class: 6631
#
# after undersampling:
#
# not payed class: 7000
#
# payed class: 6631

# %%
y_train = undersampling_data["label"]
x_train = undersampling_data.drop("label", axis=1)

# %% [markdown]
# # Train & Evaluate:

# %%
metrics = ["accuracy", 'precision', 'recall', 'f1', 'roc_auc']

# %% [markdown]
# Logistic Regression:

# %%
l_g_grid_values = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
l_g = LogisticRegression()

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(l_g, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.80538735 0.81290457 0.81227814 0.80726665 0.8081019 ]
# Average: 0.8091877218626017
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.65609756 0.73504274 0.73546512 0.67164179 0.6775    ]
# Average: 0.6951494406684381
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.25377358 0.24316682 0.23845429 0.25447691 0.25541942]
# Average: 0.24905820425728664
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.36598639 0.36543909 0.36014235 0.36910458 0.37097878]
# Average: 0.3663302396167972
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.72152127 0.73963444 0.71084905 0.70806678 0.72435865]
# Average: 0.7208860384950748
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
l_g = LogisticRegression()
optimize_model(l_g, x_train, y_train, l_g_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'C': 1}
# The best score: 0.8091877218626017
#
# precision:
# The best parameters: {'C': 0.01}
# The best score: 0.7024681168341428
#
# recall:
# The best parameters: {'C': 1}
# The best score: 0.24905820425728664
#
# f1:
# The best parameters: {'C': 1}
# The best score: 0.3663302396167972
#
# roc_auc:
# The best parameters: {'C': 1}
# The best score: 0.7208860384950748

# %% [markdown]
# Final evaluation on the test data:

# %%
l_g = LogisticRegression(C=0.01)
l_g.fit(x_train, y_train)
test_evaluate(l_g, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  4510.0   150.0
#         pay  1012.0   315.0
# Confusion matrix None
# Accuracy: 0.81
# Precision: 0.68
# Recall: 0.24
# F1: 0.35
# AUC: 0.60
#               precision    recall  f1-score   support
#
#      not pay       0.82      0.97      0.89      4660
#          pay       0.68      0.24      0.35      1327
#
#     accuracy                           0.81      5987
#    macro avg       0.75      0.60      0.62      5987
# weighted avg       0.79      0.81      0.77      5987

# %% [markdown]
# The model can't distinguish between the two classes completly (AUC = 0.5) and predict all the instances as (not payed) == (the majority)

# %% [markdown]
# Decision Tree:

# %%
d_t = DecisionTreeClassifier()

# %%
d_t_grid_values = {'criterion': ["gini", "entropy"],
                   'splitter': ["best", "random"],}

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(d_t, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.72436834 0.74399666 0.71726874 0.71246607 0.73021508]
# Average: 0.725662977657131
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.39911111 0.41355932 0.37533274 0.37444543 0.38838475]
# Average: 0.3901666720548711
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.40754717 0.45711593 0.39585297 0.39773798 0.40999057]
# Average: 0.41364892500844697
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.40386385 0.44385027 0.37323623 0.38686131 0.40852246]
# Average: 0.40326682440452466
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.61233777 0.64274305 0.60640596 0.60027967 0.61377158]
# Average: 0.6151076054441105
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
d_t = DecisionTreeClassifier()
                
optimize_model(d_t, x_train, y_train, d_t_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'criterion': 'entropy', 'splitter': 'best'}
# The best score: 0.7291710169137607
#
# precision:
# The best parameters: {'criterion': 'entropy', 'splitter': 'best'}
# The best score: 0.4005015247924744
#
# recall:
# The best parameters: {'criterion': 'gini', 'splitter': 'best'}
# The best score: 0.41893087688723707
#
# f1:
# The best parameters: {'criterion': 'entropy', 'splitter': 'best'}
# The best score: 0.40282686834571074
#
# roc_auc:
# The best parameters: {'criterion': 'entropy', 'splitter': 'best'}
# The best score: 0.6204935638068203

# %% [markdown]
# Final evaluation on the test data:

# %%
d_t = DecisionTreeClassifier(criterion = 'gini', splitter = 'best')
d_t.fit(x_train, y_train)
test_evaluate(d_t, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  3247.0  1413.0
#         pay   764.0   563.0
# Confusion matrix None
# Accuracy: 0.64
# Precision: 0.28
# Recall: 0.42
# F1: 0.34
# AUC: 0.56
#               precision    recall  f1-score   support
#
#      not pay       0.81      0.70      0.75      4660
#          pay       0.28      0.42      0.34      1327
#
#     accuracy                           0.64      5987
#    macro avg       0.55      0.56      0.54      5987
# weighted avg       0.69      0.64      0.66      5987

# %% [markdown]
# Random forest:

# %%
r_f = RandomForestClassifier()

# %%
r_f_grid_values = {'max_depth': [10, 20, 30, 50, 100],
                    'n_estimators': [10, 20, 40, 80, 100],
                    'criterion': ["gini", "entropy"]}

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(r_f, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.81227814 0.82543328 0.81478388 0.81123408 0.82271873]
# Average: 0.8172896220505326
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.63414634 0.68204283 0.65942029 0.63265306 0.6726094 ]
# Average: 0.6561743852950067
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.37075472 0.399623   0.33930254 0.34967012 0.38548539]
# Average: 0.3689671545178098
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.47170935 0.50089659 0.45527452 0.44051251 0.48019208]
# Average: 0.46971701002164956
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.76392224 0.78752293 0.76727293 0.75193823 0.77196449]
# Average: 0.768524164614105
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
r_f = RandomForestClassifier()
                
optimize_model(r_f, x_train, y_train, r_f_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 80}
# The best score: 0.8207558989350595
#
# precision:
# The best parameters: {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100}
# The best score: 0.6810105013993653
#
# recall:
# The best parameters: {'criterion': 'gini', 'max_depth': 50, 'n_estimators': 80}
# The best score: 0.3676480002845305
#
# f1:
# The best parameters: {'criterion': 'gini', 'max_depth': 50, 'n_estimators': 80}
# The best score: 0.4733796387915398
#
# roc_auc:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 80}
# The best score: 0.7819567748574516

# %% [markdown]
# Final evaluation on the test data:

# %%
r_f = RandomForestClassifier(max_depth = 100, n_estimators = 100, criterion = 'entropy')
r_f.fit(x_train, y_train)
test_evaluate(r_f, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  4523.0   137.0
#         pay  1064.0   263.0
# Confusion matrix None
# Accuracy: 0.80
# Precision: 0.66
# Recall: 0.20
# F1: 0.30
# AUC: 0.58
#               precision    recall  f1-score   support
#
#      not pay       0.81      0.97      0.88      4660
#          pay       0.66      0.20      0.30      1327
#
#     accuracy                           0.80      5987
#    macro avg       0.73      0.58      0.59      5987
# weighted avg       0.78      0.80      0.75      5987

# %% [markdown]
# # Deep Neural network:

# %% [markdown]
# Metrics:

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model = Sequential()
model.add(Dense(12, input_dim=24, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', precision_m, recall_m, f1_m,])
# fit the keras model on the dataset
model.fit(np.array(x_train), np.array(y_train), epochs=50, batch_size=100, validation_split=0.2)
model.evaluate(x=x_test, y=y_test)
# Out:
# Epoch 1/50
# 192/192 [==============================] - 16s 5ms/step - loss: 27.8750 - accuracy: 0.6687 - precision_m: 0.0998 - recall_m: 0.2054 - f1_m: 0.0818 - val_loss: 9.0660 - val_accuracy: 0.7791 - val_precision_m: 0.0625 - val_recall_m: 0.0027 - val_f1_m: 0.0052
# Epoch 2/50
# 192/192 [==============================] - 0s 2ms/step - loss: 3.7037 - accuracy: 0.6632 - precision_m: 0.2048 - recall_m: 0.2336 - f1_m: 0.1122 - val_loss: 8.1463 - val_accuracy: 0.7787 - val_precision_m: 0.0521 - val_recall_m: 0.0027 - val_f1_m: 0.0052
# Epoch 3/50
# 192/192 [==============================] - 0s 2ms/step - loss: 5.0621 - accuracy: 0.6803 - precision_m: 0.2613 - recall_m: 0.2151 - f1_m: 0.1158 - val_loss: 2.1034 - val_accuracy: 0.7797 - val_precision_m: 0.3611 - val_recall_m: 0.0296 - val_f1_m: 0.0539
# Epoch 4/50
# 192/192 [==============================] - 0s 2ms/step - loss: 2.7909 - accuracy: 0.6777 - precision_m: 0.3257 - recall_m: 0.2486 - f1_m: 0.1565 - val_loss: 2.1419 - val_accuracy: 0.7793 - val_precision_m: 0.3559 - val_recall_m: 0.0347 - val_f1_m: 0.0619
# Epoch 5/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.7072 - accuracy: 0.6845 - precision_m: 0.3823 - recall_m: 0.2507 - f1_m: 0.1761 - val_loss: 1.8481 - val_accuracy: 0.7807 - val_precision_m: 0.4479 - val_recall_m: 0.0478 - val_f1_m: 0.0849
# Epoch 6/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.8298 - accuracy: 0.6934 - precision_m: 0.4123 - recall_m: 0.2651 - f1_m: 0.1993 - val_loss: 2.0807 - val_accuracy: 0.7807 - val_precision_m: 0.4149 - val_recall_m: 0.0442 - val_f1_m: 0.0783
# Epoch 7/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.3374 - accuracy: 0.7020 - precision_m: 0.4263 - recall_m: 0.2772 - f1_m: 0.2187 - val_loss: 1.6404 - val_accuracy: 0.3316 - val_precision_m: 0.2336 - val_recall_m: 0.8873 - val_f1_m: 0.3684
# Epoch 8/50
# 192/192 [==============================] - 0s 2ms/step - loss: 2.9036 - accuracy: 0.6745 - precision_m: 0.3484 - recall_m: 0.2791 - f1_m: 0.1734 - val_loss: 4.2513 - val_accuracy: 0.7799 - val_precision_m: 0.2778 - val_recall_m: 0.0153 - val_f1_m: 0.0287
# Epoch 9/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.6940 - accuracy: 0.7139 - precision_m: 0.4586 - recall_m: 0.2873 - f1_m: 0.2449 - val_loss: 0.8950 - val_accuracy: 0.4746 - val_precision_m: 0.2640 - val_recall_m: 0.7645 - val_f1_m: 0.3903
# Epoch 10/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.8239 - accuracy: 0.7180 - precision_m: 0.4878 - recall_m: 0.3232 - f1_m: 0.2885 - val_loss: 1.5252 - val_accuracy: 0.7820 - val_precision_m: 0.5122 - val_recall_m: 0.0499 - val_f1_m: 0.0888
# Epoch 11/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.6902 - accuracy: 0.7011 - precision_m: 0.4762 - recall_m: 0.2620 - f1_m: 0.1979 - val_loss: 0.5014 - val_accuracy: 0.8075 - val_precision_m: 0.6011 - val_recall_m: 0.4032 - val_f1_m: 0.4760
# Epoch 12/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.0803 - accuracy: 0.7152 - precision_m: 0.4590 - recall_m: 0.2881 - f1_m: 0.2406 - val_loss: 0.6828 - val_accuracy: 0.7904 - val_precision_m: 0.6227 - val_recall_m: 0.1369 - val_f1_m: 0.2176
# Epoch 13/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.4520 - accuracy: 0.7060 - precision_m: 0.4458 - recall_m: 0.2648 - f1_m: 0.2136 - val_loss: 1.4800 - val_accuracy: 0.3700 - val_precision_m: 0.2415 - val_recall_m: 0.8615 - val_f1_m: 0.3755
# Epoch 14/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.2688 - accuracy: 0.7026 - precision_m: 0.4709 - recall_m: 0.2859 - f1_m: 0.2333 - val_loss: 0.6975 - val_accuracy: 0.7901 - val_precision_m: 0.6351 - val_recall_m: 0.1285 - val_f1_m: 0.2074
# Epoch 15/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.7614 - precision_m: 0.5404 - recall_m: 0.2887 - f1_m: 0.3105 - val_loss: 0.5803 - val_accuracy: 0.7269 - val_precision_m: 0.4152 - val_recall_m: 0.5587 - val_f1_m: 0.4725
# Epoch 16/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7827 - accuracy: 0.7453 - precision_m: 0.5441 - recall_m: 0.3151 - f1_m: 0.3114 - val_loss: 0.4866 - val_accuracy: 0.8110 - val_precision_m: 0.6328 - val_recall_m: 0.3574 - val_f1_m: 0.4506
# Epoch 17/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.8173 - accuracy: 0.7399 - precision_m: 0.4942 - recall_m: 0.2806 - f1_m: 0.2741 - val_loss: 0.5134 - val_accuracy: 0.8068 - val_precision_m: 0.5810 - val_recall_m: 0.4549 - val_f1_m: 0.5049
# Epoch 18/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7442 - accuracy: 0.7478 - precision_m: 0.5165 - recall_m: 0.2861 - f1_m: 0.2810 - val_loss: 0.6206 - val_accuracy: 0.7918 - val_precision_m: 0.6717 - val_recall_m: 0.1211 - val_f1_m: 0.1999
# Epoch 19/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7556 - accuracy: 0.7414 - precision_m: 0.5206 - recall_m: 0.2850 - f1_m: 0.2711 - val_loss: 0.6740 - val_accuracy: 0.7878 - val_precision_m: 0.6597 - val_recall_m: 0.0917 - val_f1_m: 0.1571
# Epoch 20/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.9068 - accuracy: 0.7265 - precision_m: 0.4691 - recall_m: 0.2697 - f1_m: 0.2405 - val_loss: 1.5744 - val_accuracy: 0.7830 - val_precision_m: 0.4965 - val_recall_m: 0.0336 - val_f1_m: 0.0622
# Epoch 21/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.7554 - precision_m: 0.5237 - recall_m: 0.2723 - f1_m: 0.2881 - val_loss: 0.7720 - val_accuracy: 0.5423 - val_precision_m: 0.2830 - val_recall_m: 0.6994 - val_f1_m: 0.4010
# Epoch 22/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.0542 - accuracy: 0.7249 - precision_m: 0.4107 - recall_m: 0.2694 - f1_m: 0.2203 - val_loss: 0.9766 - val_accuracy: 0.4469 - val_precision_m: 0.2562 - val_recall_m: 0.7860 - val_f1_m: 0.3845
# Epoch 23/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7791 - accuracy: 0.7338 - precision_m: 0.4880 - recall_m: 0.2450 - f1_m: 0.2259 - val_loss: 1.2054 - val_accuracy: 0.7822 - val_precision_m: 0.4410 - val_recall_m: 0.0236 - val_f1_m: 0.0445
# Epoch 24/50
# 192/192 [==============================] - 0s 2ms/step - loss: 1.1687 - accuracy: 0.7251 - precision_m: 0.3685 - recall_m: 0.2258 - f1_m: 0.1722 - val_loss: 2.5393 - val_accuracy: 0.7793 - val_precision_m: 0.1042 - val_recall_m: 0.0046 - val_f1_m: 0.0089
# Epoch 25/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.8385 - accuracy: 0.7443 - precision_m: 0.4786 - recall_m: 0.2480 - f1_m: 0.2332 - val_loss: 0.4728 - val_accuracy: 0.8064 - val_precision_m: 0.6477 - val_recall_m: 0.2652 - val_f1_m: 0.3702
# Epoch 26/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.6203 - accuracy: 0.7581 - precision_m: 0.5609 - recall_m: 0.2621 - f1_m: 0.2755 - val_loss: 0.5064 - val_accuracy: 0.7964 - val_precision_m: 0.6698 - val_recall_m: 0.1591 - val_f1_m: 0.2525
# Epoch 27/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.6450 - accuracy: 0.7584 - precision_m: 0.5261 - recall_m: 0.2520 - f1_m: 0.2652 - val_loss: 0.7539 - val_accuracy: 0.5446 - val_precision_m: 0.2829 - val_recall_m: 0.6912 - val_f1_m: 0.3994
# Epoch 28/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7562 - accuracy: 0.7255 - precision_m: 0.5036 - recall_m: 0.2573 - f1_m: 0.2278 - val_loss: 0.5170 - val_accuracy: 0.7952 - val_precision_m: 0.6692 - val_recall_m: 0.1383 - val_f1_m: 0.2254
# Epoch 29/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.7696 - precision_m: 0.5805 - recall_m: 0.2428 - f1_m: 0.2796 - val_loss: 0.6051 - val_accuracy: 0.7874 - val_precision_m: 0.6333 - val_recall_m: 0.0716 - val_f1_m: 0.1249
# Epoch 30/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7132 - accuracy: 0.7497 - precision_m: 0.4837 - recall_m: 0.2497 - f1_m: 0.2423 - val_loss: 0.4786 - val_accuracy: 0.8106 - val_precision_m: 0.6398 - val_recall_m: 0.3299 - val_f1_m: 0.4291
# Epoch 31/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7728 - precision_m: 0.6114 - recall_m: 0.2466 - f1_m: 0.2861 - val_loss: 0.4837 - val_accuracy: 0.8002 - val_precision_m: 0.7810 - val_recall_m: 0.1312 - val_f1_m: 0.2196
# Epoch 32/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.7715 - precision_m: 0.5827 - recall_m: 0.2448 - f1_m: 0.2788 - val_loss: 0.7388 - val_accuracy: 0.7843 - val_precision_m: 0.5312 - val_recall_m: 0.0403 - val_f1_m: 0.0735
# Epoch 33/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5296 - accuracy: 0.7857 - precision_m: 0.6306 - recall_m: 0.2550 - f1_m: 0.3100 - val_loss: 0.4770 - val_accuracy: 0.8039 - val_precision_m: 0.7127 - val_recall_m: 0.1910 - val_f1_m: 0.2946
# Epoch 34/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5723 - accuracy: 0.7683 - precision_m: 0.5595 - recall_m: 0.2203 - f1_m: 0.2537 - val_loss: 0.4948 - val_accuracy: 0.7987 - val_precision_m: 0.7101 - val_recall_m: 0.1458 - val_f1_m: 0.2360
# Epoch 35/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5395 - accuracy: 0.7872 - precision_m: 0.5501 - recall_m: 0.2259 - f1_m: 0.2752 - val_loss: 0.4701 - val_accuracy: 0.8064 - val_precision_m: 0.7012 - val_recall_m: 0.2185 - val_f1_m: 0.3254
# Epoch 36/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.7646 - accuracy: 0.7706 - precision_m: 0.5356 - recall_m: 0.2325 - f1_m: 0.2647 - val_loss: 0.5774 - val_accuracy: 0.7870 - val_precision_m: 0.5663 - val_recall_m: 0.0554 - val_f1_m: 0.0984
# Epoch 37/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5164 - accuracy: 0.7889 - precision_m: 0.5816 - recall_m: 0.2153 - f1_m: 0.2718 - val_loss: 0.4789 - val_accuracy: 0.8012 - val_precision_m: 0.7173 - val_recall_m: 0.1623 - val_f1_m: 0.2587
# Epoch 38/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5604 - accuracy: 0.7776 - precision_m: 0.5413 - recall_m: 0.2240 - f1_m: 0.2560 - val_loss: 0.4904 - val_accuracy: 0.7987 - val_precision_m: 0.7202 - val_recall_m: 0.1407 - val_f1_m: 0.2297
# Epoch 39/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.7829 - precision_m: 0.6259 - recall_m: 0.2262 - f1_m: 0.2909 - val_loss: 0.4791 - val_accuracy: 0.8083 - val_precision_m: 0.6240 - val_recall_m: 0.3272 - val_f1_m: 0.4236
# Epoch 40/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5205 - accuracy: 0.7822 - precision_m: 0.6079 - recall_m: 0.2312 - f1_m: 0.2847 - val_loss: 0.5577 - val_accuracy: 0.7421 - val_precision_m: 0.4285 - val_recall_m: 0.4921 - val_f1_m: 0.4544
# Epoch 41/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5672 - accuracy: 0.7702 - precision_m: 0.5368 - recall_m: 0.2467 - f1_m: 0.2686 - val_loss: 0.4677 - val_accuracy: 0.8068 - val_precision_m: 0.6947 - val_recall_m: 0.2318 - val_f1_m: 0.3396
# Epoch 42/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5779 - accuracy: 0.7610 - precision_m: 0.5026 - recall_m: 0.2109 - f1_m: 0.2268 - val_loss: 0.4734 - val_accuracy: 0.8102 - val_precision_m: 0.7056 - val_recall_m: 0.2465 - val_f1_m: 0.3587
# Epoch 43/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.7901 - precision_m: 0.5924 - recall_m: 0.2070 - f1_m: 0.2643 - val_loss: 0.4714 - val_accuracy: 0.8014 - val_precision_m: 0.7225 - val_recall_m: 0.1626 - val_f1_m: 0.2594
# Epoch 44/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.7618 - precision_m: 0.5521 - recall_m: 0.2054 - f1_m: 0.2302 - val_loss: 0.6175 - val_accuracy: 0.7849 - val_precision_m: 0.5590 - val_recall_m: 0.0398 - val_f1_m: 0.0730
# Epoch 45/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5260 - accuracy: 0.7828 - precision_m: 0.6146 - recall_m: 0.2160 - f1_m: 0.2688 - val_loss: 0.4769 - val_accuracy: 0.8079 - val_precision_m: 0.6259 - val_recall_m: 0.3107 - val_f1_m: 0.4104
# Epoch 46/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7697 - precision_m: 0.5948 - recall_m: 0.2219 - f1_m: 0.2580 - val_loss: 0.4990 - val_accuracy: 0.8079 - val_precision_m: 0.5987 - val_recall_m: 0.3782 - val_f1_m: 0.4591
# Epoch 47/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4888 - accuracy: 0.7987 - precision_m: 0.6353 - recall_m: 0.2064 - f1_m: 0.2822 - val_loss: 0.4761 - val_accuracy: 0.8010 - val_precision_m: 0.7438 - val_recall_m: 0.1541 - val_f1_m: 0.2496
# Epoch 48/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4910 - accuracy: 0.7942 - precision_m: 0.6417 - recall_m: 0.1968 - f1_m: 0.2676 - val_loss: 0.5374 - val_accuracy: 0.7874 - val_precision_m: 0.6115 - val_recall_m: 0.0642 - val_f1_m: 0.1135
# Epoch 49/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5349 - accuracy: 0.7790 - precision_m: 0.5783 - recall_m: 0.2006 - f1_m: 0.2391 - val_loss: 0.5463 - val_accuracy: 0.7830 - val_precision_m: 0.4375 - val_recall_m: 0.0297 - val_f1_m: 0.0549
# Epoch 50/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.5327 - accuracy: 0.7795 - precision_m: 0.5776 - recall_m: 0.1986 - f1_m: 0.2451 - val_loss: 0.7483 - val_accuracy: 0.5256 - val_precision_m: 0.2663 - val_recall_m: 0.6530 - val_f1_m: 0.3762
# 188/188 [==============================] - 1s 2ms/step - loss: 0.7576 - accuracy: 0.5273 - precision_m: 0.2706 - recall_m: 0.6653 - f1_m: 0.3741
# [0.7576056718826294,
#  0.5273091793060303,
#  0.2705850899219513,
#  0.6653037071228027,
#  0.3740612864494324]
