# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import OrdinalEncoder
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/ML homework/Copy of default of credit card clients.csv")

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [30000 rows x 25 columns]

# %% [markdown]
# # Helper Function

# %%
def preprocessing_(data):
    # get rid of missing values in MARRIAGE column
    data = data[data["MARRIAGE"] != 0]   
    
    # get rid of missing values in EDUCATION column
    data = data[data["EDUCATION"] != 0]    
    
    # discritize the AGE attribute to 6 interval
    data["AGE"] = pd.cut(data["AGE"], 6, labels=["AGE20", "AGE30", "AGE40", "AGE50", "AGE60", "AGE70"] )    
    #ordinal encoding
    encoder = OrdinalEncoder()
    # transform data
    data["AGE"] = encoder.fit_transform(np.array(data["AGE"]).reshape(-1, 1))
    
    return data

def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    """pretty print for confusion matrixes"""
    columnwidth = max([len(x) for x in labels] + [5])  # 5 is value length
    empty_cell = " " * columnwidth
    # Print header
    print("    " + empty_cell, end=" ")
    for label in labels:
        print("%{0}s".format(columnwidth) % label, end=" ")
    print()
    # Print rows
    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % label1, end=" ")
        for j in range(len(labels)):
            cell = "%{0}.1f".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            print(cell, end=" ")
        print()

        
def train_evaluate_val(model, x_train, y_train, folds, metrics):
    for metric in metrics:
        scores = cross_val_score(model, x_train, y_train, cv=folds, scoring = metric)
        print(f'{metric}:')
        print(f'Cross-validation: {scores}')
        print(f"Average: {scores.mean()}")
        print("----------------------------------------------------------")
    
def test_evaluate(model, x_test, y_test):
    prediction = model.predict(x_test)
    # prediction_prob = model.predict_proba(x_test)
    confusion = confusion_matrix(y_test, prediction)
    print("Confusion matrix",print_cm(confusion, ['Not pay', 'pay']))
    print('Accuracy: {:.2f}'.format(accuracy_score(y_test, prediction)))
    print('Precision: {:.2f}'.format(precision_score(y_test, prediction)))
    print('Recall: {:.2f}'.format(recall_score(y_test, prediction)))
    print('F1: {:.2f}'.format(f1_score(y_test, prediction)))
    print('AUC: {:.2f}'.format(roc_auc_score(y_test, prediction)))
    print(classification_report(y_test, prediction, target_names=['not pay', 'pay']))
    # precision_recall_curve(y_test, prediction_prob)

def optimize_model(model, x_train, y_train, parameters, metrics):
    for metric in metrics:
        print(f'{metric}:')
        grid_clf = GridSearchCV(model, param_grid = parameters, scoring = metric)
        grid_clf.fit(x_train, y_train)
        best_parameter = grid_clf.best_params_
        best_score = grid_clf.best_score_
        print(f"The best parameters: {best_parameter}\nThe best score: {best_score}\n")

# %% [markdown]
# # Prepare the data:

# %%
data = preprocessing_(data)

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 0          1      20000    2  ...         0         0                           1
# 1          2     120000    2  ...         0      2000                           1
# 2          3      90000    2  ...      1000      5000                           0
# 3          4      50000    2  ...      1069      1000                           0
# 4          5      50000    1  ...       689       679                           0
# ...      ...        ...  ...  ...       ...       ...                         ...
# 29995  29996     220000    1  ...      5000      1000                           0
# 29996  29997     150000    1  ...         0         0                           0
# 29997  29998      30000    1  ...      2000      3100                           1
# 29998  29999      80000    1  ...     52964      1804                           1
# 29999  30000      50000    1  ...      1000      1000                           1
#
# [29932 rows x 25 columns]

# %% [markdown]
# # combinning features and generate a high level features:

# %% [markdown]
# Combination one: combin all the preivous payements history of every person which will make a new feature represent the dealy of every person for pay his bills

# %% [markdown]
# Make the new feature:("payment_history")

# %%
data["payment_delay"] = data['PAY_0'] + data['PAY_2'] + data['PAY_3'] + data['PAY_4'] + data['PAY_5'] + data['PAY_6']

# %%
data["payment_delay"]
# Out:
# 0       -2
# 1        3
# 2        0
# 3        0
# 4       -2
#         ..
# 29995    0
# 29996   -4
# 29997    8
# 29998   -1
# 29999    0
# Name: payment_delay, Length: 29932, dtype: int64

# %% [markdown]
# Make the new feature:("payment_delay_amount")

# %%
data['payment_delay_amount'] = (data['BILL_AMT1'] - data['PAY_AMT1']) + (data['BILL_AMT2'] - data['PAY_AMT2']) + (data['BILL_AMT3'] - data['PAY_AMT3']) + (data['BILL_AMT4'] - data['PAY_AMT4']) + (data['BILL_AMT5'] - data['PAY_AMT5']) + (data['BILL_AMT6'] - data['PAY_AMT6'])

# %%
data['payment_delay_amount']
# Out:
# 0          7015
# 1         12077
# 2         90635
# 3        222946
# 4         50290
#           ...
# 29995    682799
# 29996      6692
# 29997     39196
# 29998    119430
# 29999    222566
# Name: payment_delay_amount, Length: 29932, dtype: int64

# %% [markdown]
# Make the new feature:("total_payment_amount")

# %%
data["total_payment_amount"] = data['PAY_AMT1'] + data['PAY_AMT2'] + data['PAY_AMT3'] + data['PAY_AMT4'] + data['PAY_AMT5'] + data['PAY_AMT6']

# %%
data["total_payment_amount"]
# Out:
# 0           689
# 1          5000
# 2         11018
# 3          8388
# 4         59049
#           ...
# 29995     42550
# 29996     14490
# 29997     31300
# 29998    147181
# 29999      8308
# Name: total_payment_amount, Length: 29932, dtype: int64

# %% [markdown]
# # Split the data:

# %%
y = undersampling_data["default payment next month"]
data = undersampling_data.drop("default payment next month", axis=1)

# x_train, x_test, y_train, y_test = train_test_split(data, y, test_size=0.2, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(data[['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'payment_delay', 'payment_delay_amount', 'total_payment_amount']], y, test_size=0.2, random_state=42)#'LIMIT_BAL' 'delay_amount'

# %% [markdown]
# Normalization:

# %%
scaler = preprocessing.StandardScaler().fit(np.array(x_train["payment_delay_amount"]).reshape(-1, 1))
x_train["payment_delay_amount"] = scaler.transform(np.array(x_train["payment_delay_amount"]).reshape(-1, 1))
x_test["payment_delay_amount"] = scaler.transform(np.array(x_test["payment_delay_amount"]).reshape(-1, 1))

scaler1 = preprocessing.StandardScaler().fit(np.array(x_train["total_payment_amount"]).reshape(-1, 1))
x_train["total_payment_amount"] = scaler1.transform(np.array(x_train["total_payment_amount"]).reshape(-1, 1))
x_test["total_payment_amount"] = scaler1.transform(np.array(x_test["total_payment_amount"]).reshape(-1, 1))

scaler2 = preprocessing.StandardScaler().fit(np.array(x_train["LIMIT_BAL"]).reshape(-1, 1))
x_train["LIMIT_BAL"] = scaler2.transform(np.array(x_train["LIMIT_BAL"]).reshape(-1, 1))
x_test["LIMIT_BAL"] = scaler2.transform(np.array(x_test["LIMIT_BAL"]).reshape(-1, 1))

x_train
# Out:
#        LIMIT_BAL  SEX  ...  payment_delay_amount  total_payment_amount
# 1481    1.109952    1  ...              2.877147              0.561698
# 565    -1.058180    2  ...              0.074317             -0.221095
# 11589  -0.094566    2  ...             -0.653865              0.243542
# 5378    1.993265    2  ...             -0.688092             -0.080351
# 8287   -1.138482    2  ...             -0.672366             -0.513118
# ...          ...  ...  ...                   ...                   ...
# 1971   -0.496072    1  ...              0.332965             -0.268963
# 9886   -1.058180    1  ...             -0.431132             -0.443413
# 285    -0.977879    1  ...             -0.223417             -0.395316
# 4923    0.547844    2  ...              1.760967              0.416281
# 10094  -0.817277    2  ...             -0.125602             -0.409707
#
# [10904 rows x 8 columns]

# %% [markdown]
# # undersampling:

# %%
# the unbalanecd classes
class_0 = x_train[y_train == 0]
class_1 = x_train[y_train == 1]

print("before undersampling:\n")
print(f"not payed class: {len(class_0)}\n") #18641

print(f"payed class: {len(class_1)}\n") #5304

# under sample the dominent class(not payed)
class_0 = class_0[0:6001]
print("after undersampling:\n")
print(f"not payed class: {len(class_0)}\n")
# adding label as not payed
y_0 = np.zeros(len(class_0))
y_0 = pd.DataFrame(y_0, columns=["label"])

print(f"payed class: {len(class_1)}\n")
# adding label as payed
y_1 = np.ones(len(class_1))
y_1 = pd.DataFrame(y_1, columns=["label"])

# concatinate the new balanced data
undersampling_data_samples = pd.concat([class_0, class_1], ignore_index=True)
undersampling_data_label = pd.concat([y_0, y_1], ignore_index=True)
undersampling_data_samples["label"] = undersampling_data_label


# shuffling the data
undersampling_data = shuffle(undersampling_data_samples)
undersampling_data
# Out:
# before undersampling:
#
# not payed class: 23301
#
# payed class: 6631
#
# after undersampling:
#
# not payed class: 7000
#
# payed class: 6631

# %%
y_train = undersampling_data["label"]
x_train = undersampling_data.drop("label", axis=1)

# %% [markdown]
# # Train & Evaluate:

# %%
metrics = ["accuracy", 'precision', 'recall', 'f1', 'roc_auc']

# %% [markdown]
# Logistic Regression:

# %%
l_g_grid_values = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
l_g = LogisticRegression()

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(l_g, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.64144888 0.64465841 0.64007336 0.63594681 0.65825688]
# Average: 0.6440768690399573
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.64632885 0.65167364 0.64893617 0.64308342 0.6580773 ]
# Average: 0.6496198776184503
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.58685446 0.58497653 0.57276995 0.57183099 0.62406015]
# Average: 0.5880984150517138
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.61515748 0.61652647 0.6084788  0.60536779 0.64061746]
# Average: 0.6172296022412295
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.68322101 0.68906726 0.68550112 0.67630202 0.7008078 ]
# Average: 0.6869798410661415
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
l_g = LogisticRegression()
optimize_model(l_g, x_train, y_train, l_g_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'C': 0.001}
# The best score: 0.6503124145560701
#
# precision:
# The best parameters: {'C': 0.001}
# The best score: 0.6615117013085914
#
# recall:
# The best parameters: {'C': 10}
# The best score: 0.5882862084789438
#
# f1:
# The best parameters: {'C': 0.001}
# The best score: 0.6187621965257659
#
# roc_auc:
# The best parameters: {'C': 100}
# The best score: 0.6869874122746921

# %% [markdown]
# Final evaluation on the test data:

# %%
l_g = LogisticRegression(C=10)
l_g.fit(x_train, y_train)
test_evaluate(l_g, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay   988.0   432.0
#         pay   523.0   784.0
# Confusion matrix None
# Accuracy: 0.65
# Precision: 0.64
# Recall: 0.60
# F1: 0.62
# AUC: 0.65
#               precision    recall  f1-score   support
#
#      not pay       0.65      0.70      0.67      1420
#          pay       0.64      0.60      0.62      1307
#
#     accuracy                           0.65      2727
#    macro avg       0.65      0.65      0.65      2727
# weighted avg       0.65      0.65      0.65      2727

# %% [markdown]
# Decision Tree:

# %%
d_t = DecisionTreeClassifier()

# %%
d_t_grid_values = {'max_depth': [10,20,30,50,100],
                   'criterion': ["gini", "entropy"],
                   'splitter': ["best", "random"],}

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(d_t, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.60614397 0.62769372 0.62219166 0.60981201 0.61376147]
# Average: 0.6159205650131032
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.59828244 0.62183236 0.61486486 0.59337626 0.59925094]
# Average: 0.6055213735132822
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.58779343 0.61502347 0.5971831  0.61784038 0.59962406]
# Average: 0.603492887147446
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.60412758 0.60669856 0.61414333 0.60893855 0.59388235]
# Average: 0.6055580753018306
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.61182838 0.63341495 0.61995768 0.60206766 0.60594952]
# Average: 0.6146436366738443
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
d_t = DecisionTreeClassifier()
                
optimize_model(d_t, x_train, y_train, d_t_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'best'}
# The best score: 0.6778264746833578
#
# precision:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'random'}
# The best score: 0.6945607389187741
#
# recall:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'best'}
# The best score: 0.6470666101874404
#
# f1:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'best'}
# The best score: 0.6604815318890209
#
# roc_auc:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'splitter': 'random'}
# The best score: 0.7206349903799328

# %% [markdown]
# Final evaluation on the test data:

# %%
d_t = DecisionTreeClassifier(max_depth=10, criterion = 'entropy', splitter = 'best')
d_t.fit(x_train, y_train)
test_evaluate(d_t, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  1042.0   378.0
#         pay   482.0   825.0
# Confusion matrix None
# Accuracy: 0.68
# Precision: 0.69
# Recall: 0.63
# F1: 0.66
# AUC: 0.68
#               precision    recall  f1-score   support
#
#      not pay       0.68      0.73      0.71      1420
#          pay       0.69      0.63      0.66      1307
#
#     accuracy                           0.68      2727
#    macro avg       0.68      0.68      0.68      2727
# weighted avg       0.68      0.68      0.68      2727

# %% [markdown]
# Random Forest:

# %%
r_f = RandomForestClassifier()

# %%
r_f_grid_values = {'max_depth': [10, 20, 30, 50, 100],
                    'n_estimators': [10, 20, 40, 80, 100],
                    'criterion': ["gini", "entropy"]}

# %% [markdown]
# train and evaluate using cross validation:

# %%
train_evaluate_val(r_f, x_train, y_train, 5, metrics)
# Out:
# accuracy:
# Cross-validation: [0.68500688 0.68133884 0.69188446 0.68042182 0.69220183]
# Average: 0.6861707658720644
# ----------------------------------------------------------
# precision:
# Cross-validation: [0.6884273  0.68237705 0.69366563 0.67889908 0.69330669]
# Average: 0.6873351506008321
# ----------------------------------------------------------
# recall:
# Cross-validation: [0.65821596 0.63098592 0.61971831 0.63474178 0.66541353]
# Average: 0.6418151011331144
# ----------------------------------------------------------
# f1:
# Cross-validation: [0.67436267 0.65979381 0.65340627 0.64702995 0.68507752]
# Average: 0.663934043942812
# ----------------------------------------------------------
# roc_auc:
# Cross-validation: [0.74235238 0.73954011 0.74265107 0.73792216 0.75329874]
# Average: 0.7431528903345243
# ----------------------------------------------------------

# %% [markdown]
# optimize the model using grid search:

# %%
r_f = RandomForestClassifier()
                
optimize_model(r_f, x_train, y_train, r_f_grid_values, metrics)
# Out:
# accuracy:
# The best parameters: {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100}
# The best score: 0.7050631601529472
#
# precision:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100}
# The best score: 0.7162975445055613
#
# recall:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 80}
# The best score: 0.6557126972360479
#
# f1:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 80}
# The best score: 0.6846428560370592
#
# roc_auc:
# The best parameters: {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 100}
# The best score: 0.7648397501591325

# %% [markdown]
# Final evaluation on the test data:

# %%
r_f = RandomForestClassifier(max_depth = 10, n_estimators = 80, criterion = 'entropy')
r_f.fit(x_train, y_train)
test_evaluate(r_f, x_test, y_test)
# Out:
#             Not pay     pay
#     Not pay  1060.0   360.0
#         pay   450.0   857.0
# Confusion matrix None
# Accuracy: 0.70
# Precision: 0.70
# Recall: 0.66
# F1: 0.68
# AUC: 0.70
#               precision    recall  f1-score   support
#
#      not pay       0.70      0.75      0.72      1420
#          pay       0.70      0.66      0.68      1307
#
#     accuracy                           0.70      2727
#    macro avg       0.70      0.70      0.70      2727
# weighted avg       0.70      0.70      0.70      2727

# %% [markdown]
# # Deep Neural network:

# %% [markdown]
# Metrics:

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', precision_m, recall_m, f1_m,])
# fit the keras model on the dataset
model.fit(np.array(x_train), np.array(y_train), epochs=100, batch_size=100, validation_split=0.2)
model.evaluate(x=x_test, y=y_test)
# Out:
# Epoch 1/100
# 873/873 [==============================] - 3s 2ms/step - loss: 0.6383 - accuracy: 0.6254 - precision_m: 0.6505 - recall_m: 0.6353 - f1_m: 0.5893 - val_loss: 0.5882 - val_accuracy: 0.6919 - val_precision_m: 0.7438 - val_recall_m: 0.5299 - val_f1_m: 0.5905
# Epoch 2/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5977 - accuracy: 0.6816 - precision_m: 0.7419 - recall_m: 0.5138 - f1_m: 0.5749 - val_loss: 0.5843 - val_accuracy: 0.6942 - val_precision_m: 0.7463 - val_recall_m: 0.5379 - val_f1_m: 0.5961
# Epoch 3/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5989 - accuracy: 0.6866 - precision_m: 0.7213 - recall_m: 0.5397 - f1_m: 0.5853 - val_loss: 0.5807 - val_accuracy: 0.6992 - val_precision_m: 0.6878 - val_recall_m: 0.6567 - val_f1_m: 0.6483
# Epoch 4/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5900 - accuracy: 0.6906 - precision_m: 0.7081 - recall_m: 0.5778 - f1_m: 0.6075 - val_loss: 0.5877 - val_accuracy: 0.6809 - val_precision_m: 0.6413 - val_recall_m: 0.7447 - val_f1_m: 0.6697
# Epoch 5/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5931 - accuracy: 0.6898 - precision_m: 0.7089 - recall_m: 0.6251 - f1_m: 0.6345 - val_loss: 0.5816 - val_accuracy: 0.7006 - val_precision_m: 0.6636 - val_recall_m: 0.7366 - val_f1_m: 0.6775
# Epoch 6/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5937 - accuracy: 0.6849 - precision_m: 0.6842 - recall_m: 0.6493 - f1_m: 0.6389 - val_loss: 0.5792 - val_accuracy: 0.6937 - val_precision_m: 0.7067 - val_recall_m: 0.6249 - val_f1_m: 0.6364
# Epoch 7/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5819 - accuracy: 0.7008 - precision_m: 0.7246 - recall_m: 0.6347 - f1_m: 0.6485 - val_loss: 0.5866 - val_accuracy: 0.6832 - val_precision_m: 0.6354 - val_recall_m: 0.7768 - val_f1_m: 0.6792
# Epoch 8/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5900 - accuracy: 0.6889 - precision_m: 0.7066 - recall_m: 0.6428 - f1_m: 0.6424 - val_loss: 0.5761 - val_accuracy: 0.7029 - val_precision_m: 0.7089 - val_recall_m: 0.6401 - val_f1_m: 0.6473
# Epoch 9/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5868 - accuracy: 0.6962 - precision_m: 0.7017 - recall_m: 0.6612 - f1_m: 0.6546 - val_loss: 0.5773 - val_accuracy: 0.6937 - val_precision_m: 0.7238 - val_recall_m: 0.5701 - val_f1_m: 0.6079
# Epoch 10/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5809 - accuracy: 0.7012 - precision_m: 0.7140 - recall_m: 0.6223 - f1_m: 0.6331 - val_loss: 0.5764 - val_accuracy: 0.6988 - val_precision_m: 0.7348 - val_recall_m: 0.5596 - val_f1_m: 0.6070
# Epoch 11/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5937 - accuracy: 0.6837 - precision_m: 0.6928 - recall_m: 0.6268 - f1_m: 0.6316 - val_loss: 0.5823 - val_accuracy: 0.6965 - val_precision_m: 0.7358 - val_recall_m: 0.5586 - val_f1_m: 0.6072
# Epoch 12/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5934 - accuracy: 0.6840 - precision_m: 0.6873 - recall_m: 0.6552 - f1_m: 0.6412 - val_loss: 0.5738 - val_accuracy: 0.6992 - val_precision_m: 0.7084 - val_recall_m: 0.6352 - val_f1_m: 0.6427
# Epoch 13/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5854 - accuracy: 0.6934 - precision_m: 0.7123 - recall_m: 0.6184 - f1_m: 0.6336 - val_loss: 0.5752 - val_accuracy: 0.7070 - val_precision_m: 0.7012 - val_recall_m: 0.6661 - val_f1_m: 0.6598
# Epoch 14/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5935 - accuracy: 0.6796 - precision_m: 0.6960 - recall_m: 0.6468 - f1_m: 0.6405 - val_loss: 0.5717 - val_accuracy: 0.7020 - val_precision_m: 0.7271 - val_recall_m: 0.6180 - val_f1_m: 0.6388
# Epoch 15/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7003 - precision_m: 0.7188 - recall_m: 0.6551 - f1_m: 0.6560 - val_loss: 0.5797 - val_accuracy: 0.6969 - val_precision_m: 0.7410 - val_recall_m: 0.5336 - val_f1_m: 0.5929
# Epoch 16/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5874 - accuracy: 0.6943 - precision_m: 0.7068 - recall_m: 0.6444 - f1_m: 0.6411 - val_loss: 0.5709 - val_accuracy: 0.7043 - val_precision_m: 0.7121 - val_recall_m: 0.6451 - val_f1_m: 0.6499
# Epoch 17/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5857 - accuracy: 0.6941 - precision_m: 0.7012 - recall_m: 0.6484 - f1_m: 0.6441 - val_loss: 0.5711 - val_accuracy: 0.7084 - val_precision_m: 0.7088 - val_recall_m: 0.6613 - val_f1_m: 0.6582
# Epoch 18/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5838 - accuracy: 0.6920 - precision_m: 0.7096 - recall_m: 0.6627 - f1_m: 0.6551 - val_loss: 0.5710 - val_accuracy: 0.6946 - val_precision_m: 0.7229 - val_recall_m: 0.5828 - val_f1_m: 0.6162
# Epoch 19/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5823 - accuracy: 0.6976 - precision_m: 0.7114 - recall_m: 0.6586 - f1_m: 0.6537 - val_loss: 0.5718 - val_accuracy: 0.6969 - val_precision_m: 0.7115 - val_recall_m: 0.6212 - val_f1_m: 0.6349
# Epoch 20/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5761 - accuracy: 0.7039 - precision_m: 0.7106 - recall_m: 0.6635 - f1_m: 0.6593 - val_loss: 0.5760 - val_accuracy: 0.7084 - val_precision_m: 0.6718 - val_recall_m: 0.7257 - val_f1_m: 0.6772
# Epoch 21/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5845 - accuracy: 0.6935 - precision_m: 0.6968 - recall_m: 0.6721 - f1_m: 0.6589 - val_loss: 0.5710 - val_accuracy: 0.6974 - val_precision_m: 0.7180 - val_recall_m: 0.5968 - val_f1_m: 0.6242
# Epoch 22/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5816 - accuracy: 0.7001 - precision_m: 0.7076 - recall_m: 0.6449 - f1_m: 0.6463 - val_loss: 0.5719 - val_accuracy: 0.7052 - val_precision_m: 0.7031 - val_recall_m: 0.6651 - val_f1_m: 0.6586
# Epoch 23/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5783 - accuracy: 0.7035 - precision_m: 0.7177 - recall_m: 0.6698 - f1_m: 0.6670 - val_loss: 0.5749 - val_accuracy: 0.7020 - val_precision_m: 0.7010 - val_recall_m: 0.6523 - val_f1_m: 0.6501
# Epoch 24/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5826 - accuracy: 0.6987 - precision_m: 0.7025 - recall_m: 0.6727 - f1_m: 0.6619 - val_loss: 0.5709 - val_accuracy: 0.7070 - val_precision_m: 0.6940 - val_recall_m: 0.6835 - val_f1_m: 0.6645
# Epoch 25/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5785 - accuracy: 0.6987 - precision_m: 0.6875 - recall_m: 0.6610 - f1_m: 0.6471 - val_loss: 0.5735 - val_accuracy: 0.6978 - val_precision_m: 0.6808 - val_recall_m: 0.6866 - val_f1_m: 0.6581
# Epoch 26/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5779 - accuracy: 0.7001 - precision_m: 0.7060 - recall_m: 0.6644 - f1_m: 0.6608 - val_loss: 0.5727 - val_accuracy: 0.7107 - val_precision_m: 0.6939 - val_recall_m: 0.6963 - val_f1_m: 0.6709
# Epoch 27/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5716 - accuracy: 0.7099 - precision_m: 0.7124 - recall_m: 0.6723 - f1_m: 0.6640 - val_loss: 0.5726 - val_accuracy: 0.7024 - val_precision_m: 0.7072 - val_recall_m: 0.6328 - val_f1_m: 0.6421
# Epoch 28/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5745 - accuracy: 0.7029 - precision_m: 0.6970 - recall_m: 0.6597 - f1_m: 0.6510 - val_loss: 0.5738 - val_accuracy: 0.7079 - val_precision_m: 0.6948 - val_recall_m: 0.6921 - val_f1_m: 0.6679
# Epoch 29/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5720 - accuracy: 0.7097 - precision_m: 0.7226 - recall_m: 0.6872 - f1_m: 0.6763 - val_loss: 0.5736 - val_accuracy: 0.7061 - val_precision_m: 0.7071 - val_recall_m: 0.6499 - val_f1_m: 0.6513
# Epoch 30/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5782 - accuracy: 0.6977 - precision_m: 0.6927 - recall_m: 0.6738 - f1_m: 0.6573 - val_loss: 0.5733 - val_accuracy: 0.7011 - val_precision_m: 0.7053 - val_recall_m: 0.6440 - val_f1_m: 0.6464
# Epoch 31/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5754 - accuracy: 0.6954 - precision_m: 0.6913 - recall_m: 0.6601 - f1_m: 0.6476 - val_loss: 0.5773 - val_accuracy: 0.6997 - val_precision_m: 0.6621 - val_recall_m: 0.7214 - val_f1_m: 0.6707
# Epoch 32/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5761 - accuracy: 0.6970 - precision_m: 0.6942 - recall_m: 0.6776 - f1_m: 0.6612 - val_loss: 0.5694 - val_accuracy: 0.7066 - val_precision_m: 0.6985 - val_recall_m: 0.6679 - val_f1_m: 0.6572
# Epoch 33/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5781 - accuracy: 0.6981 - precision_m: 0.7067 - recall_m: 0.6572 - f1_m: 0.6546 - val_loss: 0.5724 - val_accuracy: 0.7111 - val_precision_m: 0.6766 - val_recall_m: 0.7266 - val_f1_m: 0.6792
# Epoch 34/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5830 - accuracy: 0.6909 - precision_m: 0.6920 - recall_m: 0.6623 - f1_m: 0.6485 - val_loss: 0.5733 - val_accuracy: 0.7001 - val_precision_m: 0.7334 - val_recall_m: 0.5863 - val_f1_m: 0.6239
# Epoch 35/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5820 - accuracy: 0.6969 - precision_m: 0.7079 - recall_m: 0.6684 - f1_m: 0.6601 - val_loss: 0.5755 - val_accuracy: 0.6988 - val_precision_m: 0.6617 - val_recall_m: 0.7300 - val_f1_m: 0.6733
# Epoch 36/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5739 - accuracy: 0.7066 - precision_m: 0.7120 - recall_m: 0.6824 - f1_m: 0.6679 - val_loss: 0.5768 - val_accuracy: 0.7075 - val_precision_m: 0.6775 - val_recall_m: 0.7245 - val_f1_m: 0.6764
# Epoch 37/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5764 - accuracy: 0.6977 - precision_m: 0.6968 - recall_m: 0.6647 - f1_m: 0.6542 - val_loss: 0.5716 - val_accuracy: 0.7093 - val_precision_m: 0.7015 - val_recall_m: 0.6754 - val_f1_m: 0.6629
# Epoch 38/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5771 - accuracy: 0.7030 - precision_m: 0.7073 - recall_m: 0.6795 - f1_m: 0.6671 - val_loss: 0.5730 - val_accuracy: 0.7024 - val_precision_m: 0.7174 - val_recall_m: 0.6154 - val_f1_m: 0.6369
# Epoch 39/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5668 - accuracy: 0.7073 - precision_m: 0.7165 - recall_m: 0.6747 - f1_m: 0.6676 - val_loss: 0.5738 - val_accuracy: 0.7024 - val_precision_m: 0.7205 - val_recall_m: 0.6133 - val_f1_m: 0.6356
# Epoch 40/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5846 - accuracy: 0.6913 - precision_m: 0.6909 - recall_m: 0.6640 - f1_m: 0.6518 - val_loss: 0.5776 - val_accuracy: 0.7038 - val_precision_m: 0.6598 - val_recall_m: 0.7492 - val_f1_m: 0.6804
# Epoch 41/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5731 - accuracy: 0.7047 - precision_m: 0.7018 - recall_m: 0.6914 - f1_m: 0.6685 - val_loss: 0.5750 - val_accuracy: 0.7075 - val_precision_m: 0.6948 - val_recall_m: 0.6885 - val_f1_m: 0.6656
# Epoch 42/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7047 - precision_m: 0.7111 - recall_m: 0.6707 - f1_m: 0.6650 - val_loss: 0.5744 - val_accuracy: 0.7088 - val_precision_m: 0.7073 - val_recall_m: 0.6646 - val_f1_m: 0.6588
# Epoch 43/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5729 - accuracy: 0.7049 - precision_m: 0.7100 - recall_m: 0.6673 - f1_m: 0.6623 - val_loss: 0.5734 - val_accuracy: 0.7093 - val_precision_m: 0.6864 - val_recall_m: 0.7037 - val_f1_m: 0.6721
# Epoch 44/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5775 - accuracy: 0.7012 - precision_m: 0.7018 - recall_m: 0.6837 - f1_m: 0.6684 - val_loss: 0.5739 - val_accuracy: 0.7116 - val_precision_m: 0.6752 - val_recall_m: 0.7458 - val_f1_m: 0.6866
# Epoch 45/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.6977 - precision_m: 0.6988 - recall_m: 0.6843 - f1_m: 0.6665 - val_loss: 0.5733 - val_accuracy: 0.7043 - val_precision_m: 0.6847 - val_recall_m: 0.6988 - val_f1_m: 0.6672
# Epoch 46/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5817 - accuracy: 0.7019 - precision_m: 0.6975 - recall_m: 0.6878 - f1_m: 0.6692 - val_loss: 0.5743 - val_accuracy: 0.7061 - val_precision_m: 0.6854 - val_recall_m: 0.6839 - val_f1_m: 0.6617
# Epoch 47/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5709 - accuracy: 0.7039 - precision_m: 0.6991 - recall_m: 0.6570 - f1_m: 0.6517 - val_loss: 0.5737 - val_accuracy: 0.7079 - val_precision_m: 0.6890 - val_recall_m: 0.6867 - val_f1_m: 0.6634
# Epoch 48/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7053 - precision_m: 0.7041 - recall_m: 0.6864 - f1_m: 0.6713 - val_loss: 0.5789 - val_accuracy: 0.7052 - val_precision_m: 0.6636 - val_recall_m: 0.7448 - val_f1_m: 0.6798
# Epoch 49/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5701 - accuracy: 0.7051 - precision_m: 0.6993 - recall_m: 0.6836 - f1_m: 0.6636 - val_loss: 0.5758 - val_accuracy: 0.7070 - val_precision_m: 0.6838 - val_recall_m: 0.7124 - val_f1_m: 0.6743
# Epoch 50/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5779 - accuracy: 0.6971 - precision_m: 0.6946 - recall_m: 0.6776 - f1_m: 0.6583 - val_loss: 0.5776 - val_accuracy: 0.6969 - val_precision_m: 0.6603 - val_recall_m: 0.7133 - val_f1_m: 0.6648
# Epoch 51/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.7084 - precision_m: 0.7023 - recall_m: 0.6930 - f1_m: 0.6714 - val_loss: 0.5747 - val_accuracy: 0.7043 - val_precision_m: 0.7019 - val_recall_m: 0.6558 - val_f1_m: 0.6526
# Epoch 52/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5715 - accuracy: 0.7091 - precision_m: 0.7011 - recall_m: 0.6839 - f1_m: 0.6673 - val_loss: 0.5754 - val_accuracy: 0.7139 - val_precision_m: 0.6852 - val_recall_m: 0.7113 - val_f1_m: 0.6753
# Epoch 53/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5693 - accuracy: 0.7068 - precision_m: 0.7073 - recall_m: 0.6742 - f1_m: 0.6632 - val_loss: 0.5746 - val_accuracy: 0.7006 - val_precision_m: 0.6942 - val_recall_m: 0.6598 - val_f1_m: 0.6525
# Epoch 54/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5729 - accuracy: 0.6996 - precision_m: 0.7012 - recall_m: 0.6766 - f1_m: 0.6633 - val_loss: 0.5763 - val_accuracy: 0.7024 - val_precision_m: 0.6854 - val_recall_m: 0.6814 - val_f1_m: 0.6596
# Epoch 55/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5762 - accuracy: 0.6943 - precision_m: 0.6888 - recall_m: 0.6831 - f1_m: 0.6582 - val_loss: 0.5752 - val_accuracy: 0.7001 - val_precision_m: 0.6934 - val_recall_m: 0.6598 - val_f1_m: 0.6512
# Epoch 56/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5683 - accuracy: 0.7072 - precision_m: 0.7063 - recall_m: 0.6794 - f1_m: 0.6679 - val_loss: 0.5754 - val_accuracy: 0.7066 - val_precision_m: 0.6908 - val_recall_m: 0.6922 - val_f1_m: 0.6663
# Epoch 57/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5691 - accuracy: 0.7032 - precision_m: 0.6871 - recall_m: 0.6671 - f1_m: 0.6497 - val_loss: 0.5778 - val_accuracy: 0.7029 - val_precision_m: 0.6597 - val_recall_m: 0.7524 - val_f1_m: 0.6822
# Epoch 58/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5687 - accuracy: 0.7049 - precision_m: 0.7005 - recall_m: 0.7087 - f1_m: 0.6800 - val_loss: 0.5747 - val_accuracy: 0.7043 - val_precision_m: 0.6864 - val_recall_m: 0.6776 - val_f1_m: 0.6591
# Epoch 59/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5671 - accuracy: 0.7033 - precision_m: 0.7058 - recall_m: 0.6943 - f1_m: 0.6778 - val_loss: 0.5802 - val_accuracy: 0.7006 - val_precision_m: 0.6573 - val_recall_m: 0.7516 - val_f1_m: 0.6801
# Epoch 60/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5673 - accuracy: 0.7071 - precision_m: 0.7080 - recall_m: 0.6877 - f1_m: 0.6730 - val_loss: 0.5768 - val_accuracy: 0.7102 - val_precision_m: 0.6881 - val_recall_m: 0.7026 - val_f1_m: 0.6719
# Epoch 61/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5635 - accuracy: 0.7118 - precision_m: 0.7115 - recall_m: 0.7195 - f1_m: 0.6900 - val_loss: 0.5783 - val_accuracy: 0.7020 - val_precision_m: 0.7042 - val_recall_m: 0.6491 - val_f1_m: 0.6499
# Epoch 62/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5644 - accuracy: 0.7133 - precision_m: 0.7140 - recall_m: 0.6884 - f1_m: 0.6736 - val_loss: 0.5790 - val_accuracy: 0.6997 - val_precision_m: 0.6495 - val_recall_m: 0.7525 - val_f1_m: 0.6773
# Epoch 63/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.6970 - precision_m: 0.6870 - recall_m: 0.7146 - f1_m: 0.6768 - val_loss: 0.5800 - val_accuracy: 0.7038 - val_precision_m: 0.6770 - val_recall_m: 0.7010 - val_f1_m: 0.6681
# Epoch 64/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5686 - accuracy: 0.7064 - precision_m: 0.7006 - recall_m: 0.6974 - f1_m: 0.6756 - val_loss: 0.5780 - val_accuracy: 0.7043 - val_precision_m: 0.7119 - val_recall_m: 0.6355 - val_f1_m: 0.6458
# Epoch 65/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5689 - accuracy: 0.7019 - precision_m: 0.7171 - recall_m: 0.6757 - f1_m: 0.6685 - val_loss: 0.5852 - val_accuracy: 0.6960 - val_precision_m: 0.6492 - val_recall_m: 0.7532 - val_f1_m: 0.6783
# Epoch 66/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5650 - accuracy: 0.7075 - precision_m: 0.7145 - recall_m: 0.6891 - f1_m: 0.6764 - val_loss: 0.5795 - val_accuracy: 0.7052 - val_precision_m: 0.6744 - val_recall_m: 0.7098 - val_f1_m: 0.6694
# Epoch 67/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5672 - accuracy: 0.7109 - precision_m: 0.7160 - recall_m: 0.6885 - f1_m: 0.6743 - val_loss: 0.5760 - val_accuracy: 0.7130 - val_precision_m: 0.7020 - val_recall_m: 0.6904 - val_f1_m: 0.6707
# Epoch 68/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5677 - accuracy: 0.7030 - precision_m: 0.6993 - recall_m: 0.6778 - f1_m: 0.6623 - val_loss: 0.5788 - val_accuracy: 0.7006 - val_precision_m: 0.6786 - val_recall_m: 0.6941 - val_f1_m: 0.6596
# Epoch 69/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5676 - accuracy: 0.7065 - precision_m: 0.7073 - recall_m: 0.6714 - f1_m: 0.6600 - val_loss: 0.5760 - val_accuracy: 0.7052 - val_precision_m: 0.6890 - val_recall_m: 0.6731 - val_f1_m: 0.6557
# Epoch 70/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5660 - accuracy: 0.7117 - precision_m: 0.7158 - recall_m: 0.6765 - f1_m: 0.6667 - val_loss: 0.5899 - val_accuracy: 0.6974 - val_precision_m: 0.7132 - val_recall_m: 0.6068 - val_f1_m: 0.6292
# Epoch 71/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5663 - accuracy: 0.7095 - precision_m: 0.7099 - recall_m: 0.6880 - f1_m: 0.6727 - val_loss: 0.5795 - val_accuracy: 0.7038 - val_precision_m: 0.6765 - val_recall_m: 0.7137 - val_f1_m: 0.6703
# Epoch 72/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5629 - accuracy: 0.7143 - precision_m: 0.7114 - recall_m: 0.6958 - f1_m: 0.6788 - val_loss: 0.5804 - val_accuracy: 0.7038 - val_precision_m: 0.6861 - val_recall_m: 0.6830 - val_f1_m: 0.6621
# Epoch 73/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5628 - accuracy: 0.7122 - precision_m: 0.6936 - recall_m: 0.6831 - f1_m: 0.6620 - val_loss: 0.5794 - val_accuracy: 0.7015 - val_precision_m: 0.6600 - val_recall_m: 0.7416 - val_f1_m: 0.6776
# Epoch 74/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5637 - accuracy: 0.7105 - precision_m: 0.7036 - recall_m: 0.7036 - f1_m: 0.6795 - val_loss: 0.5782 - val_accuracy: 0.7084 - val_precision_m: 0.6895 - val_recall_m: 0.6929 - val_f1_m: 0.6673
# Epoch 75/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5658 - accuracy: 0.7104 - precision_m: 0.7106 - recall_m: 0.6862 - f1_m: 0.6719 - val_loss: 0.5826 - val_accuracy: 0.7006 - val_precision_m: 0.6620 - val_recall_m: 0.7257 - val_f1_m: 0.6707
# Epoch 76/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5609 - accuracy: 0.7100 - precision_m: 0.7241 - recall_m: 0.6853 - f1_m: 0.6797 - val_loss: 0.5823 - val_accuracy: 0.6937 - val_precision_m: 0.6922 - val_recall_m: 0.6528 - val_f1_m: 0.6451
# Epoch 77/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5585 - accuracy: 0.7153 - precision_m: 0.7175 - recall_m: 0.6891 - f1_m: 0.6794 - val_loss: 0.5817 - val_accuracy: 0.7075 - val_precision_m: 0.6786 - val_recall_m: 0.7234 - val_f1_m: 0.6755
# Epoch 78/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5713 - accuracy: 0.7024 - precision_m: 0.6918 - recall_m: 0.6661 - f1_m: 0.6497 - val_loss: 0.5857 - val_accuracy: 0.6942 - val_precision_m: 0.6591 - val_recall_m: 0.7264 - val_f1_m: 0.6699
# Epoch 79/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5696 - accuracy: 0.7020 - precision_m: 0.7056 - recall_m: 0.6766 - f1_m: 0.6693 - val_loss: 0.5807 - val_accuracy: 0.7075 - val_precision_m: 0.7048 - val_recall_m: 0.6609 - val_f1_m: 0.6561
# Epoch 80/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5588 - accuracy: 0.7115 - precision_m: 0.7114 - recall_m: 0.7047 - f1_m: 0.6823 - val_loss: 0.5849 - val_accuracy: 0.6997 - val_precision_m: 0.7157 - val_recall_m: 0.6021 - val_f1_m: 0.6274
# Epoch 81/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5602 - accuracy: 0.7097 - precision_m: 0.7179 - recall_m: 0.6629 - f1_m: 0.6607 - val_loss: 0.5817 - val_accuracy: 0.7052 - val_precision_m: 0.6829 - val_recall_m: 0.7179 - val_f1_m: 0.6752
# Epoch 82/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5673 - accuracy: 0.7088 - precision_m: 0.7071 - recall_m: 0.7031 - f1_m: 0.6797 - val_loss: 0.5844 - val_accuracy: 0.6946 - val_precision_m: 0.6968 - val_recall_m: 0.6200 - val_f1_m: 0.6310
# Epoch 83/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5668 - accuracy: 0.7089 - precision_m: 0.7133 - recall_m: 0.6645 - f1_m: 0.6631 - val_loss: 0.5831 - val_accuracy: 0.7079 - val_precision_m: 0.7136 - val_recall_m: 0.6507 - val_f1_m: 0.6548
# Epoch 84/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5639 - accuracy: 0.7097 - precision_m: 0.7156 - recall_m: 0.6884 - f1_m: 0.6733 - val_loss: 0.5848 - val_accuracy: 0.6983 - val_precision_m: 0.6795 - val_recall_m: 0.7057 - val_f1_m: 0.6656
# Epoch 85/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5681 - accuracy: 0.7025 - precision_m: 0.7079 - recall_m: 0.6842 - f1_m: 0.6691 - val_loss: 0.5879 - val_accuracy: 0.6937 - val_precision_m: 0.7013 - val_recall_m: 0.6166 - val_f1_m: 0.6310
# Epoch 86/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5691 - accuracy: 0.6988 - precision_m: 0.6934 - recall_m: 0.6926 - f1_m: 0.6665 - val_loss: 0.5820 - val_accuracy: 0.7043 - val_precision_m: 0.6756 - val_recall_m: 0.6982 - val_f1_m: 0.6647
# Epoch 87/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5598 - accuracy: 0.7159 - precision_m: 0.7154 - recall_m: 0.7019 - f1_m: 0.6828 - val_loss: 0.5837 - val_accuracy: 0.6978 - val_precision_m: 0.6568 - val_recall_m: 0.7440 - val_f1_m: 0.6773
# Epoch 88/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5554 - accuracy: 0.7195 - precision_m: 0.7158 - recall_m: 0.7058 - f1_m: 0.6837 - val_loss: 0.5891 - val_accuracy: 0.6928 - val_precision_m: 0.6637 - val_recall_m: 0.7135 - val_f1_m: 0.6647
# Epoch 89/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5587 - accuracy: 0.7069 - precision_m: 0.7048 - recall_m: 0.6807 - f1_m: 0.6671 - val_loss: 0.5891 - val_accuracy: 0.7006 - val_precision_m: 0.6829 - val_recall_m: 0.6832 - val_f1_m: 0.6590
# Epoch 90/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5615 - accuracy: 0.7162 - precision_m: 0.7269 - recall_m: 0.6934 - f1_m: 0.6851 - val_loss: 0.5856 - val_accuracy: 0.6965 - val_precision_m: 0.6695 - val_recall_m: 0.6866 - val_f1_m: 0.6542
# Epoch 91/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7108 - precision_m: 0.7163 - recall_m: 0.6488 - f1_m: 0.6572 - val_loss: 0.5846 - val_accuracy: 0.6983 - val_precision_m: 0.6997 - val_recall_m: 0.6426 - val_f1_m: 0.6431
# Epoch 92/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7113 - precision_m: 0.7118 - recall_m: 0.6827 - f1_m: 0.6742 - val_loss: 0.5853 - val_accuracy: 0.6942 - val_precision_m: 0.6712 - val_recall_m: 0.6954 - val_f1_m: 0.6585
# Epoch 93/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7071 - precision_m: 0.7012 - recall_m: 0.6684 - f1_m: 0.6608 - val_loss: 0.5865 - val_accuracy: 0.6988 - val_precision_m: 0.6926 - val_recall_m: 0.6519 - val_f1_m: 0.6460
# Epoch 94/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7128 - precision_m: 0.7154 - recall_m: 0.6857 - f1_m: 0.6737 - val_loss: 0.5861 - val_accuracy: 0.6997 - val_precision_m: 0.6757 - val_recall_m: 0.6961 - val_f1_m: 0.6617
# Epoch 95/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5622 - accuracy: 0.7023 - precision_m: 0.6931 - recall_m: 0.6865 - f1_m: 0.6652 - val_loss: 0.5861 - val_accuracy: 0.6933 - val_precision_m: 0.6597 - val_recall_m: 0.7287 - val_f1_m: 0.6715
# Epoch 96/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5591 - accuracy: 0.7086 - precision_m: 0.7033 - recall_m: 0.6905 - f1_m: 0.6688 - val_loss: 0.5844 - val_accuracy: 0.7006 - val_precision_m: 0.7021 - val_recall_m: 0.6409 - val_f1_m: 0.6438
# Epoch 97/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5618 - accuracy: 0.7109 - precision_m: 0.7156 - recall_m: 0.6590 - f1_m: 0.6603 - val_loss: 0.5888 - val_accuracy: 0.7033 - val_precision_m: 0.6705 - val_recall_m: 0.7200 - val_f1_m: 0.6707
# Epoch 98/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7190 - precision_m: 0.7212 - recall_m: 0.7064 - f1_m: 0.6856 - val_loss: 0.5869 - val_accuracy: 0.6992 - val_precision_m: 0.6802 - val_recall_m: 0.6820 - val_f1_m: 0.6565
# Epoch 99/100
# 873/873 [==============================] - 1s 2ms/step - loss: 0.5556 - accuracy: 0.7107 - precision_m: 0.7188 - recall_m: 0.6610 - f1_m: 0.6618 - val_loss: 0.5869 - val_accuracy: 0.7006 - val_precision_m: 0.6743 - val_recall_m: 0.7124 - val_f1_m: 0.6685
# Epoch 100/100
# 873/873 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.7171 - precision_m: 0.7135 - recall_m: 0.6911 - f1_m: 0.6767 - val_loss: 0.5878 - val_accuracy: 0.7075 - val_precision_m: 0.6995 - val_recall_m: 0.6855 - val_f1_m: 0.6652
# 86/86 [==============================] - 1s 2ms/step - loss: 0.6002 - accuracy: 0.6839 - precision_m: 0.6774 - recall_m: 0.6614 - f1_m: 0.6618
# [0.6001665592193604,
#  0.6839017271995544,
#  0.6773856282234192,
#  0.6613942980766296,
#  0.6617529988288879]
